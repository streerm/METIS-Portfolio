# %% [markdown]
# 1. Scrape list of cities with hyperlinks from 'All Cities' page (BeautifulSoup)

# %%
import pandas as pd

from bs4 import BeautifulSoup
import requests
import time, os

# %%
# Complete list of cities (provided by site manager)

url = 'https://www.expatistan.com/cost-of-living/all-cities' 

response = requests.get(url)
#response.text
response.status_code  # 2** = successful read
# Out:
# 200

# %%
page = response.text
soup = BeautifulSoup(page, "lxml")
# print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://www.expatistan.com/cost-of-living/all-cities" hreflang="en" rel="alternate"/>
#   <link href="https://www.expatistan.com/es/costo-de-vida/todas-las-ciudades" hreflang="es" rel="alternate"/>
#   <link href="https://www.expatistan.com/pt/custo-de-vida/todas-as-cidades" hreflang="pt" rel="alternate"/>
#   <title>
#    Cost of Living Comparisons, 2021 data.
#   </title>
#   <meta content="Cost of Living comparisons for thousands of cities. Fully up-to-date cost of living comparisons, including prices of 52 products and services." name="description"/>
#   <meta content="Cost of Living Comparisons, 2021 data." property="og:title"/>
#   <meta content="Cost of Living comparisons for thousands of cities. Fully up-to-date cost of living comparisons, including prices of 52 products and services." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="//d2y05869ftj0yg.cloudfront.net/images/expatistan_fb_icon.jpg" property="og:image"/>
#   <meta content="https://www.expatistan.com" property="og:url"/>
#   <meta content="Expatistan, cost of living comparisons" property="og:site_name"/>
#   <!--<meta property="og:locale" content="en" />-->
#   <!--<meta property="og:locale:alternate" content="es" />-->
#   <meta content="502752123,gerardo.robledillo" property="fb:admins"/>
#   <meta content="145554152152105" property="fb:page_id"/>
#   <link href="https://www.expatistan.com/cost-of-living/all-cities" rel="canonical"/>
#   <!--[if lt IE 9]>
#   <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
#   <script>
#    if (typeof whenDocReady === "function") {
#     // already declared, do nothing
#   } else {
#     function whenDocReady(fn) {
#       // see if DOM is already available
#       if (document.readyState === "complete" || document.readyState === "interactive") {
#         // call on next available tick
#         setTimeout(fn, 1);
#       } else {
#         document.addEventListener("DOMContentLoaded", fn);
#       }
#     }
#   }
#   if (typeof whenScriptsLoaded === "function") {
#     // already declared, do nothing
#   } else {
#     function whenScriptsLoaded(fn) {
#       // see if DOM is already available
#       if (typeof scriptsAreReady === "function") {
#         // call on next available tick
#         setTimeout(fn, 1);
#       } else {
#         document.getElementById("expatistan.079.ahfm").addEventListener('load', fn);
#       }
#     }
#   }
#   </script>
#   <style>
#    @charset "UTF-8"; #select_city .label.title,body,form{margin:0} a,body,th{font-weight:400} .percent,table.comparison span.cheaper,table.comparison span.expensiver{line-height:23px} .prices td.price,table.comparison .percent span.content{font-family:"Lucida Console",Monaco,monospace} .percent,.prices td a,a.button,body,h1 strong,h2 strong,input,input[type=submit],select{font-family:"Helvetica Neue",helvetica,verdana,sans-serif} .colindex .regions li,.itemBadge .undertxt{font-variant:small-caps} #breadcrumbs li,.right-widget li,ul li{list-style-type:none} body{font-size:16px;background-color:#fff;color:#454342} a,a:visited{color:#09c;text-decoration:none} #breadcrumbs a.current,#recent_comparisons a,.downplayed-links a,.right-widget h1,.right-widget h2,.right-widget h3,.right-widget h4,a.downlighted,h1,h2,h3,h4{color:#454342;font-weight:400} a:hover{text-decoration:underline} input,select{font-weight:400} ul li{margin-bottom:.5em} .cf{zoom:1} .cf:after{content:".";display:block;height:0;clear:both;visibility:hidden} .block{float:right} .block.first,.home-module.left,.percent{float:left} .blocks-60-40 div.first{width:60%} .blocks-60-40 .block{width:39.6%} .close_message_area{position:absolute;top:4px;right:4px;cursor:pointer} #header,.flags{position:relative} h1{margin:0 0 .8em;padding:0 0 0 20px;font-size:2.5em;line-height:1.4em} .right-widget h2,h2{margin:0 0 .8em;font-size:1.5em} h1 strong,h2 strong{font-weight:400;color:#000} .percent{margin:0;outline:0;padding:1px 6px 0 22px;font-size:15px;color:#666;border:none} #wrapper{width:1010px;margin:0 auto} #header{width:948px;padding-right:20px} #header img{border:0} #breadcrumbs{line-height:30px;overflow:hidden;margin:6px 0;padding:6px;border:1px solid silver;font-size:14px} #breadcrumbs li{float:left;margin:0 3px} #breadcrumbs a{height:30px;display:block;padding:0;text-decoration:none} #breadcrumbs a:after{content:" / ";color:gray;padding:0 .25em 0 .5em} #breadcrumbs a.current:after{content:"";content:none} #breadcrumbs a:hover{color:#35acc5} .comparison{margin:2em 0 3em;padding:0 0 1em} .comparison h1{color:#000;padding:0} .comparison p{margin:0;text-align:right} .prices h1{padding:0;text-align:center;color:#454342} .prices table{margin:0 0 1em;table-layout:fixed;border-spacing:0 8px} .prices tr.expandable th.clickable{background:url(//d2y05869ftj0yg.cloudfront.net/images/sprite/page-elements.png) 0 -202px no-repeat} .prices td.icon,.prices td.item-name,.prices td.percent,.prices td.price{margin:0;border-top:1px solid #eee;font-size:14px} .prices tr.city-names td{text-align:center} .prices td.item-name{padding:.67em 0 .67em .67em;font-size:16px;line-height:1.3em} .single-price .city-1,td.price{white-space:nowrap} .blueBtn2,a.button,input[type=submit]{white-space:normal;outline:0;transition:.2s;cursor:pointer;text-decoration:none} .prices tr:last-child td{border-bottom:0} .prices .percent{float:none;margin-top:5px;padding-left:0} #copyright,#footer .langs,#humanity-check .center,.centered,.ins_a,.percent,.price,.summary{text-align:center} .single-price{margin:3em 0 1em 20px;font-size:18px} .single-price h1{font-size:1.5em} .breakdown-chart{min-height:418px} #recent_comparisons.blue-links h2 a{color:#09c;font-weight:700} .single-price div{margin-top:4em} .currency-change a,table.comparison th.categoryEditLink{font-size:.9em} .breakdown-title{padding:1em .5em 0;text-align:center;font-weight:700} .compartxt,table.comparison th.categoryEditLink a{font-weight:400!important} .comparison p.breakdown-subtitle{font-style:italic;text-align:center;color:#ccc} #footer{border-top:1px solid #ccc;margin-top:3em;padding:12px 0;font-size:1.2em;color:#999} #error_message,.flags{border:2px solid orange;background:#ffc} #footer a{color:#999;font-weight:400} #footer h3{text-align:center;margin:2px;font-weight:400} #footer h4{text-align:center;margin:10px 0 20px;font-weight:400} #error_message{padding:1em;margin:2em 0;font-size:18px} .flags{padding:0 1em} .flags h5{font-size:14px;font-weight:400;ma ...
#   .dropdown-toggle,.nav-collapse,.nav-toggle{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none} .dropdown-toggle,.logo,.nav-toggle{-webkit-tap-highlight-color:transparent} .logo,.nav-collapse a,.nav-toggle{text-decoration:none;float:left} .logo,.nav-toggle:before{color:#454545;line-height:55px} .nav-collapse ul{margin:0;padding:0;display:block} .nav-collapse li{display:block;float:left;width:100%} .desktop-submenu-arrow,.nav-collapse li ul{display:none} .js .nav-collapse,.js .nav-collapse .dropdown ul{clip:rect(0 0 0 0);max-height:0;position:absolute;display:block;overflow:hidden;zoom:1} .nav-collapse .dropdown .dropdown.opened>ul,.nav-collapse .dropdown.opened>ul,.nav-toggle{position:relative} .nav-collapse .dropdown.opened ul,.nav-collapse.opened{max-height:9999px} .dropdown-toggle,.nav-toggle{-webkit-touch-callout:none;-o-user-select:none;user-select:none} .headernav{background:#e1eff4;height:3.5em;float:left;width:100%;font-size:1.1em} .headernav ul li{margin-bottom:0} #responsiveNav{z-index:999} .logo{font-weight:700;padding:0 20px} .nav-collapse,.nav-collapse *{-moz-box-sizing:border-box;-webkit-box-sizing:border-box;box-sizing:border-box} .nav-collapse{-o-user-select:none;user-select:none} .nav-collapse,.nav-collapse ul{list-style:none;width:100%;float:left} .nav-collapse a{color:#454545;width:100%;background:#e1eff4;border-bottom:1px solid rgba(0,0,0,.15);padding:.7em 1em} .nav-collapse a:active{color:rgba(18,43,156,.5)} @font-face{font-family:responsivenav;src:url(https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.eot);src:url(https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.eot?#iefix) format("embedded-opentype"),url(https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.ttf) format("truetype"),url(https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.woff) format("woff"),url(https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.svg#responsivenav) format("svg");font-weight:400;font-style:normal;font-display:swap} .nav-toggle{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;-webkit-touch-callout:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;text-indent:-999px;overflow:hidden;width:70px;height:55px} .nav-toggle:before{font-family:responsivenav,sans-serif;font-style:normal;font-weight:400;font-variant:normal;font-size:28px;text-transform:none;position:absolute;content:"\2261";text-indent:0;text-align:center;speak:none;width:100%;top:0;left:0} .nav-toggle.active::before{font-size:24px;content:"x"} .dropdown ul a{background:#c5e1ea;padding-left:1.5em} .dropdown ul ul a{background:#aecfd9;padding-left:1.5em} .dropdown ul ul ul a{background:#9bbbc1} .dropdown ul{background:#3e8da8} .dropdown ul.wide li{width:140%} .dropdown ul ul{border:0;padding:0} .dropdown-toggle:after{content:"+";font-size:1.5em;line-height:.8;float:right} .dropdown.opened>.dropdown-toggle:after{content:"–"} @media screen and (min-width:40em){ .js .nav-collapse,.nav-collapse .dropdown{position:relative} .js .nav-collapse.closed,.js .nav-collapse.closed .dropdown ul{max-height:none} .js .nav-collapse .dropdown ul,.nav-toggle{display:none} .headernav{margin:.4em 0} .nav-collapse{width:auto;float:left} .nav-collapse li{width:auto} .nav-collapse a{margin:0;padding:16px 1.5em;float:left;text-align:center;border-bottom:0;border-right:1px solid #fff} .nav-collapse li:last-child a{border:0} .js .nav-collapse,.js .nav-collapse .dropdown ul{max-height:none;overflow:visible} .desktop-submenu-arrow{display:inline} .dropdown ul .dropdown-toggle:after,.dropdown-toggle:after{content:""} .nav-collapse a:hover{color:rgba(18,43,156,.5)} .nav-collapse .dropdown li{width:100%;white-space:nowrap} .nav-collapse .dropdown ul a{text-align:left;border:0;white-space:nowrap} .nav-collapse .dropdown ul ul li{width:12em;z-index:9998} .nav-col ...
#   </style>
#   <script>
#    var _gaq = [['_setAccount', 'UA-6791730-1'], ['_trackPageview'], ['_trackPageLoadTime']];
#   </script>
#   <script async="async" id="expatistan.079.ahfm" src="https://d2y05869ftj0yg.cloudfront.net/javascripts/cache/expatistan.079.ahfm.js" type="text/javascript">
#   </script>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="F47618516423F3A8E60A452A6355C810" name="msvalidate.01"/>
#   <!-- Begin Cookie Consent plugin by Silktide - http://silktide.com/cookieconsent -->
#   <script async="" type="text/javascript">
#    window.cookieconsent_options = {"message":"We and selected partners use cookies or similar technologies as specified in the cookie policy. You can consent to the use of such technologies by closing this notice, by scrolling this page, by interacting with any link or button outside of this notice or by continuing to browse otherwise.","dismiss":"Got it!","learnMore":"More info","link":"https://www.expatistan.com/tos#cookies","theme":"light-bottom"};
#   </script>
#   <script async="" src="//d2y05869ftj0yg.cloudfront.net/javascripts/cookieconsent2.1.0.9.min.js" type="text/javascript">
#   </script>
#   <!-- End Cookie Consent plugin -->
#   <link as="script" href="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.eot" rel="preload" type="font/eot"/>
#   <link as="font" crossorigin="anonymous" href="https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.ttf" rel="preload" type="font/ttf"/>
#   <link as="font" crossorigin="anonymous" href="https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="https://d2y05869ftj0yg.cloudfront.net/stylesheets/responsive-nav/icons/responsivenav.svg" rel="preload" type="font/svg"/>
#  </head>
#  <body class="mobile">
#   <div id="wrapper">
#    <!-- start header -->
#    <div class="cf" id="header">
#     <div class="centered">
#      <a href="https://www.expatistan.com/">
#       <img height="60" src="//d2y05869ftj0yg.cloudfront.net/images/expatistan_logo.190x60.png" title="Expatistan, cost of living comparisons" width="190"/>
#      </a>
#     </div>
#    </div>
#    <!-- end header -->
#    <div class="headernav" style="min-height: 63px;">
#     <div class="nav-collapse" id="responsiveNav">
#      <ul>
#       <li class="dropdown">
#        <a class="dropdown-toggle" href="#">
#         Cost of Living
#         <span class="desktop-submenu-arrow">
#          ▾
#         </span>
#        </a>
#        <ul>
#         <li>
#          <a class="event-tracked" data-action="search_by_city" data-category="navigation" data-label="by_city" href="https://www.expatistan.com/cost-of-living/city">
#           By City
#          </a>
#         </li>
#         <li>
#          <a class="event-tracked" data-action="search_by_country" data-category="navigation" data-label="by_city" href="https://www.expatistan.com/cost-of-living/country">
#           By Country
#          </a>
#         </li>
#         <li class="dropdown">
#          <a class="dropdown-toggle" href="#">
#           Comparisons
#           <span class="desktop-submenu-arrow">
#            ▸
#           </span>
#          </a>
#          <ul>
#           <li>
#            <a class="event-tracked" data-action="cost_of_living" data-category="navigation" data-label="city-comparisons" href="https://www.expatistan.com/">
#             Compare cities
#            </a>
#           </li>
#           <li>
#            <a class="event-tracked" data-action="cost_of_living" data-category="navigation" data-label="city-comparisons" href="https://www.expatistan.com/cost-of-living/country/comparison">
#             Compare countries
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown">
#          <a class="dropdown-toggle" href="#">
#           Rankings
#           <span class="desktop-submenu-arrow">
#            ▸
#           </span>
#          </a>
#          <ul>
#           <li class="dropdown">
#            <a class="dropdown-toggle" href="https://www.expatistan.com/cost-of-living/index">
#             City Rankings
#             <span class="desktop-submenu-arrow">
#              ▸
#             </span>
#            </a>
#            <ul>
#             <li>
#              <a class="event-tracked" data-action="cost_of_living" data-category="navigation" data-label="city-ranking_the-world" href="https://www.expatistan.com/cost-of-living/index">
#               The World
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_europe" href="/cost-of-living/index/europe">
#               Europe
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_north-america" href="/cost-of-living/index/north-america">
#               North America
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_latin-america" href="/cost-of-living/index/latin-america">
#               Latin America
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_asia" href="/cost-of-living/index/asia">
#               Asia
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_middle-east" href="/cost-of-living/index/middle-east">
#               Middle East
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_africa" href="/cost-of-living/index/africa">
#               Africa
#              </a>
#             </li>
#             <li>
#              <a class="event-tracked" data-action="city-cost_of_living" data-category="navigation" data-label="ranking_oceania" href="/cost-of-living/index/oceania">
#               Oceania
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown">
#            <a href="https://www.expatistan.com/cost-of-living/country/ranking">
#             Country Ranking
#            </a>
#           </li>
#           <!--<li><a href="https://www.expatistan.com/" class="event-tracked" data-category="navigation" data-action="cost_of_living" data-label="city-prices">Prices</a></li>-->
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" href="https://www.expatistan.com/salary-calculator">
#         Salary Calculator
#         <span class="desktop-submenu-arrow">
#          ▾
#         </span>
#        </a>
#        <ul class="wide">
#         <li>
#          <a class="event-tracked" data-action="reports" data-category="navigation" data-label="reports_individuals" href="https://www.expatistan.com/salary-calculator">
#           For Expats
#          </a>
#         </li>
#         <li>
#          <a class="event-tracked" data-action="reports" data-category="navigation" data-label="reports_hr" href="https://www.expatistan.com/salary-calculator/hr-services">
#           For Human Resources
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a class="event-tracked" data-action="international_schools" data-category="navigation" data-label="index" href="https://www.international-schools-database.com">
#         International Schools
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="languageOptions">
#      <ul>
#       <li class="selected" style="padding-left:0;margin-left:0;">
#        EN
#       </li>
#       <li style="padding-left:0;margin-left:0;">
#        <a href="https://www.expatistan.com/es/costo-de-vida/todas-las-ciudades" style="padding-left:0;">
#         ES
#        </a>
#       </li>
#       <li style="padding-left:0;margin-left:0;">
#        <a href="https://www.expatistan.com/pt/custo-de-vida/todas-as-cidades" style="padding-left:0;">
#         PT
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="cf" id="content">
#     <h1>
#      List of all cities included in Expatistan
#     </h1>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/afghanistan">
#        Afghanistan
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kabul">
#         Kabul
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/aland-islands">
#        Aland Islands
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mariehamn">
#         Mariehamn
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/albania">
#        Albania
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/durres">
#         Durrës
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/elbasan">
#         Elbasan
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/korce">
#         Korçë
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/shkoder">
#         Shkoder
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tirana">
#         Tirana
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vlore">
#         Vlorë
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/algeria">
#        Algeria
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ain-temouchentain-temouchent">
#         'Ain Temouchent
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/aflou">
#         Aflou
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ain-sefra">
#         Ain Sefra
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/akbou">
#         Akbou
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/algiers">
#         Algiers
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/barika">
#         Barika
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/batna-city">
#         Batna City
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/bir-el-ater">
#         Bir el Ater
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/birine">
#         Birine
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/bechar">
#         Béchar
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/bejaia">
#         Béjaïa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/chelghoum-el-aid">
#         Chelghoum el Aid
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/cheria">
#         Cheria
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/constantine">
#         Constantine
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/dar-chioukh">
#         Dar Chioukh
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/djamaa">
#         Djamaa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/drean">
#         Drean
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ech-chettia">
#         Ech Chettia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/el-eulma">
#         El Eulma
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/frenda">
#         Frenda
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/khemis-miliana">
#         Khemis Miliana
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ksar-chellala">
#         Ksar Chellala
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ksar-el-boukhari">
#         Ksar el Boukhari
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/laghouat">
#         Laghouat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/lakhdaria">
#         Lakhdaria
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/medea">
#         Medea
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/messaad">
#         Messaad
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/metlili-chaamba">
#         Metlili Chaamba
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/mostaganem">
#         Mostaganem
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/oran">
#         Oran
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/oued-rhiou">
#         Oued Rhiou
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/oum-el-bouaghi">
#         Oum el Bouaghi
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ras-el-oued">
#         Ras el Oued
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/reguiba">
#         Reguiba
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/rouissat">
#         Rouissat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/saida">
#         Saida
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sedrata">
#         Sedrata
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/sidi-bel-abbes">
#         Sidi Bel Abbes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sidi-khaled">
#         Sidi Khaled
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sig">
#         Sig
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/skikda">
#         Skikda
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sougueur">
#         Sougueur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sour-el-ghozlane">
#         Sour el Ghozlane
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/tamanghasset">
#         Tamanghasset
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tlemcen">
#         Tlemcen
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/tolga">
#         Tolga
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/andorra">
#        Andorra
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/andorra-la-vella">
#         Andorra la Vella
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/angola">
#        Angola
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/cabinda">
#         Cabinda
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/huambo">
#         Huambo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kuito">
#         Kuito
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/lobito">
#         Lobito
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/luanda">
#         Luanda
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/lubango">
#         Lubango
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/malanje">
#         Malanje
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/namibe">
#         Namibe
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/soyo">
#         Soyo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/uige">
#         Uíge
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/anguilla">
#        Anguilla
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/the-valley-anguilla">
#         The Valley, Anguilla
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/antigua-and-barbuda">
#        Antigua and Barbuda
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/st-johns-antigua-and-barbuda">
#         St. John's, Antigua and Barbuda
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/argentina">
#        Argentina
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/bahia-blanca">
#         Bahía Blanca
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/buenos-aires">
#         Buenos Aires
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/comodoro-rivadavia">
#         Comodoro Rivadavia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/concordia">
#         Concordia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/corrientes">
#         Corrientes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/cordoba">
#         Córdoba
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/formosa">
#         Formosa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/la-plata">
#         La Plata
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/la-rioja">
#         La Rioja
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mar-del-plata">
#         Mar del Plata
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mendoza">
#         Mendoza
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/neuquen">
#         Neuquén
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/posadas">
#         Posadas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/quilmes">
#         Quilmes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/resistencia">
#         Resistencia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rio-grande-tierra-del-fuego">
#         Rio Grande, Tierra del Fuego
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rosario">
#         Rosario
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rio-cuarto">
#         Río Cuarto
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/salta">
#         Salta
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-carlos-de-bariloche">
#         San Carlos de Bariloche
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-fernando-del-valle-de-catamarca">
#         San Fernando del Valle de Catamarca
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-juan-argentina">
#         San Juan
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-luis-argentina">
#         San Luis
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-martin-de-los-andes">
#         San Martin de los Andes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-nicolas-de-los-arroyos">
#         San Nicolás de los Arroyos
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-rafael">
#         San Rafael
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/santa-fe-argentina">
#         Santa Fe
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/santa-rosa">
#         Santa Rosa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/santiago-del-estero">
#         Santiago del Estero
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tandil">
#         Tandil
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tucuman">
#         Tucumán
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ushuaia">
#         Ushuaia
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/armenia">
#        Armenia
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/gyumri">
#         Gyumri
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vanadzor">
#         Vanadzor
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/yerevan">
#         Yerevan
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/aruba">
#        Aruba
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/babijn-aruba">
#         Babijn, Aruba
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/australia">
#        Australia
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/adelaide">
#         Adelaide
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/albury">
#         Albury
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ballarat">
#         Ballarat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/brisbane">
#         Brisbane
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/cairns">
#         Cairns
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/canberra">
#         Canberra
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/darwin">
#         Darwin
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/dubbo">
#         Dubbo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/geelong">
#         Geelong
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/gold-coast">
#         Gold Coast
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/hobart">
#         Hobart
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mackay">
#         Mackay
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/melbourne">
#         Melbourne
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mildura">
#         Mildura
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/newcastle-australia">
#         Newcastle
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/perth-australia">
#         Perth
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/sydney">
#         Sydney
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/toowoomba">
#         Toowoomba
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/townsville">
#         Townsville
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/wollongong">
#         Wollongong
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/austria">
#        Austria
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/graz">
#         Graz
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/innsbruck">
#         Innsbruck
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/salzburg">
#         Salzburg
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vienna">
#         Vienna
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/villach">
#         Villach
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/wels">
#         Wels
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/azerbaijan">
#        Azerbaijan
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ali-bayramli">
#         Ali Bayramli
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/baku">
#         Baku
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ganja">
#         Ganja
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/naxcivan">
#         Naxcivan
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/yevlax">
#         Yevlax
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ski">
#         Şǝki
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/bahamas">
#        Bahamas
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/nassau">
#         Nassau
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/bahrain">
#        Bahrain
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/manama">
#         Manama
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/bangladesh">
#        Bangladesh
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/bhairab-bazar">
#         Bhairab Bazar
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/bhola">
#         Bhola
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/chittagong">
#         Chittagong
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/comilla">
#         Comilla
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/coxs-bazars-bazar">
#         Cox's Bazar
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/dhaka">
#         Dhaka
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/dinajpur">
#         Dinajpur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/faridpur">
#         Faridpur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/feni">
#         Feni
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/jaipur-hat">
#         Jaipur Hat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/jamalpur">
#         Jamalpur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/kaptaimukh">
#         Kaptaimukh
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/khagrachari">
#         Khagrachari
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/khulna">
#         Khulna
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kishorganj">
#         Kishorganj
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kushtia">
#         Kushtia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/lalmanir-hat">
#         Lalmanir Hat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/moulvi-bazar">
#         Moulvi Bazar
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/narail">
#         Narail
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/nawabganj">
#         Nawabganj
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/netrakona">
#         Netrakona
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/palang">
#         Palang
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/pirojpur">
#         Pirojpur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rajshahi">
#         Rajshahi
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ramganj">
#         Ramganj
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sandwip">
#         Sandwip
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/satkhira">
#         Satkhira
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/sirajganj">
#         Sirajganj
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/sylhet">
#         Sylhet
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tangail">
#         Tangail
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/thakurgaon">
#         Thakurgaon
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/barbados">
#        Barbados
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/bridgetown">
#         Bridgetown
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/belarus">
#        Belarus
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/babruysk">
#         Babruysk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/baranavichy">
#         Baranavichy
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/brest-belarus">
#         Brest
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/homyel">
#         Homyel
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/hrodna">
#         Hrodna
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/kobryn">
#         Kobryn
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/lida">
#         Lida
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mahiliou">
#         Mahilioŭ
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/maladzyechna">
#         Maladzyechna
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mazyr">
#         Mazyr
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/minsk">
#         Minsk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/orsha">
#         Orsha
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/pinsk">
#         Pinsk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/polatsk">
#         Polatsk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/slonim">
#         Slonim
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/slutsk">
#         Slutsk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vitebsk">
#         Vitebsk
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/zhlobin">
#         Zhlobin
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/zhodzina">
#         Zhodzina
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/belgium">
#        Belgium
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/antwerp">
#         Antwerp
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/brussels">
#         Brussels
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ghent">
#         Ghent
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/hasselt">
#         Hasselt
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/leuven">
#         Leuven
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/liege">
#         Liege
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mons">
#         Mons
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/namur">
#         Namur
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ostend">
#         Ostend
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/verviers">
#         Verviers
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/belize">
#        Belize
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/belize-city">
#         Belize City
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/san-pedro-town-belize">
# ...
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/venezuela">
#        Venezuela
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/acarigua">
#         Acarigua
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/alto-barinas">
#         Alto Barinas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/anaco">
#         Anaco
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/barcelona-venezuela">
#         Barcelona
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/barquisimeto">
#         Barquisimeto
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/calabozo">
#         Calabozo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/caracas">
#         Caracas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/carupano">
#         Carúpano
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ciudad-bolivar">
#         Ciudad Bolívar
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ciudad-guayana">
#         Ciudad Guayana
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/coro">
#         Coro
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/cumana">
#         Cumaná
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/el-tigre">
#         El Tigre
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/guanare">
#         Guanare
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/maracaibo">
#         Maracaibo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/maturin">
#         Maturín
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/mucumpiz">
#         Mucumpiz
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/punto-fijo">
#         Punto Fijo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/santa-teresa">
#         Santa Teresa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/turmero">
#         Turmero
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/valencia-venezuela">
#         Valencia
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/vietnam">
#        Vietnam
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/bac-giang">
#         Bac Giang
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/bac-lieu">
#         Bac Lieu
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/buon-ma-thuot">
#         Buon Ma Thuot
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ca-mau">
#         Ca Mau
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/chau-doc">
#         Chau Doc
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/da-lat">
#         Da Lat
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/da-nang">
#         Da Nang
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/ha-long">
#         Ha Long
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/haiphong">
#         Haiphong
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/hanoi">
#         Hanoi
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ho-chi-minh-city">
#         Ho Chi Minh City
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/hoa-binh">
#         Hoa Binh
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/hue">
#         Huế
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/long-xuyen">
#         Long Xuyen
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/my-tho">
#         Mỹ Tho
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/nha-trang">
#         Nha Trang
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/phan-rang-thap-cham">
#         Phan Rang-Tháp Chàm
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/phan-thiet">
#         Phan Thiết
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/pleiku">
#         Pleiku
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/quy-nhon">
#         Quy Nhon
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/rach-gia">
#         Rach Gia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/soc-trang">
#         Soc Trang
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/tam-ky">
#         Tam Ky
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/thai-binh">
#         Thai Binh
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/thai-nguyen">
#         Thai Nguyen
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/thanh-hoa">
#         Thanh Hóa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/tra-vinh">
#         Tra Vinh
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/tuy-hoa">
#         Tuy Hoa
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/viet-tri">
#         Viet Tri
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vinh-long">
#         Vinh Long
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/vung-tau">
#         Vũng Tàu
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/yen-bai">
#         Yen Bai
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/yen-vinh">
#         Yen Vinh
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/western-sahara">
#        Western Sahara
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/dakhla">
#         Dakhla
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/el-aaiun">
#         El Aaiún
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/yemen">
#        Yemen
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/aden">
#         Aden
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/al-hudaydah">
#         Al Hudaydah
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/al-mukalla">
#         Al Mukalla
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ibb">
#         Ibb
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/sana">
#         San‘a’
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/taizz">
#         Ta`izz
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/zabid">
#         Zabid
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/zambia">
#        Zambia
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/chingola">
#         Chingola
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/chipata">
#         Chipata
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kabwe">
#         Kabwe
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kasama">
#         Kasama
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/livingstone">
#         Livingstone
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/lusaka">
#         Lusaka
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/mazabuka">
#         Mazabuka
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/mongu">
#         Mongu
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/mufulira">
#         Mufulira
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/ndola">
#         Ndola
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="three-columns" id="all-cities">
#      <h3>
#       <a href="https://www.expatistan.com/cost-of-living/country/zimbabwe">
#        Zimbabwe
#       </a>
#      </h3>
#      <ul>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/bulawayo">
#         Bulawayo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/chinhoyi">
#         Chinhoyi
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/gweru">
#         Gweru
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/harare">
#         Harare
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/kadoma">
#         Kadoma
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/rate/kwekwe">
#         Kwekwe
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/marondera">
#         Marondera
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/masvingo">
#         Masvingo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/mutare">
#         Mutare
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/zvishavane-district">
#         Zvishavane District
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="cf right-widget centered" id="mobileSearchForm">
#     <div class="right">
#      <h1>
#       Make a different comparison:
#      </h1>
#      <div id="select_city">
#       <form action="https://www.expatistan.com/cost-of-living/comparison" id="compare_form" method="GET" onsubmit="return compare_cities('header');">
#        <div class="holder" id="first_city">
#         <div class="label title">
#          Compare cost of living between cities:
#         </div>
#         <div class="input">
#          <!-- TODO: add hint_content class if value is empty -->
#          <input autocomplete="off" class="home_input city-2 hint_content" id="city_other_name" name="city[other][name]" size="18" type="text" value="where you want to move"/>
#          <input class="handle" name="city[other][handle]" type="hidden" value=""/>
#         </div>
#        </div>
#        <div class="holder" id="second_city">
#         <div class="label">
#          vs
#         </div>
#         <div class="input">
#          <input autocomplete="off" class="home_input city-1" id="city_this_name" name="city[this][name]" size="18" type="text" value="Asheville, North Carolina"/>
#          <input class="handle" name="city[this][handle]" type="hidden" value="asheville"/>
#         </div>
#        </div>
#        <div class="holder round" id="button">
#         <input class="submit" name="commit" type="submit" value="Compare!"/>
#        </div>
#       </form>
#      </div>
#      <div id="error_message" style="display:none;">
#       Please, fill in both cities
#      </div>
#     </div>
#    </div>
#    <div id="footer">
#     <h3>
#      Collaborative international cost of living index
#     </h3>
#     <h4>
#      You enter the prices, we make the comparisons
#     </h4>
#     <!-- google_ad_section_start(weight=ignore) -->
#     <div class="footerLinks">
#      <ul>
#       <li class="first">
#        <a href="https://www.expatistan.com/faq">
#         Frequently Asked Questions
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/cost-of-living/index">
#         Cost of Living Index
#        </a>
#       </li>
#       <li>
#        <a href="//www.expatistan.com/blog">
#         Blog
#        </a>
#       </li>
#      </ul>
#      <ul>
#       <li class="first">
#        <a href="https://www.expatistan.com/what-is-it">
#         What is it?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/how-does-it-work">
#         How does it work?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/who-are-we">
#         Who are we?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/security">
#         Security
#        </a>
#       </li>
#       <li>
#        <a href="mailto:gerardo@expatistan.com">
#         Contact
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/sitemap/cost-of-living/comparison">
#         Sitemap
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/tos" rel="nofollow">
#         Disclaimer
#        </a>
#       </li>
#       <li>
#        <a href="https://www.expatistan.com/privacy-policy" rel="nofollow">
#         Privacy policy
#        </a>
#       </li>
#      </ul>
#      <p id="copyright">
#       © 2009-2021 Expatistan.com
#      </p>
#      <hr/>
#      <ul class="langs">
#       <li class="first selected">
#        English
#       </li>
#       <li>
#        <a class="link" href="https://www.expatistan.com/es/costo-de-vida/todas-las-ciudades" style="margin:0">
#         Español
#        </a>
#       </li>
#       <li>
#        <a class="link" href="https://www.expatistan.com/pt/custo-de-vida/todas-as-cidades" style="margin:0">
#         Português
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- google_ad_section_end -->
#    </div>
#    <script type="text/javascript">
#     (function(d, t) {
#     var g = d.createElement(t),
#         s = d.getElementsByTagName(t)[0];
#     g.async = g.src = '//www.google-analytics.com/ga.js';
#     s.parentNode.insertBefore(g, s);
#   }(document, 'script'));
#    </script>
#    <script type="text/javascript">
#     whenScriptsLoaded(function(){ var a=Math.floor(Math.random()*11); var b=Math.floor(Math.random()*11);var x=jQuery.post('https://www.expatistan.com/ajax/humanize', {a: a, b: b, c: a+b}) });
#    </script>
#   </div>
#   <script async="" data-ad-client="ca-pub-2483520005599174" defer="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    var nav = null;
#   whenScriptsLoaded(function(){
#     var nav = responsiveNav("#responsiveNav");
#         setTimeout(function(){nav.resize();console.log('nav.resize')},1000);
#   });
#   </script>
#  </body>
# </html>

# %%
# # Toolbox

# %%script false

# for link in soup.find_all('a')[:50]:
#     print(link, '\n')

# for element in soup.find_all(class_='mojo-navigation-tab'):
#     print(element.prettify())

# for link in soup.find_all('div', id='three-columns')[:50]:
#     print(link, '\n')

# soup.find_all('li').size

# %%
# # Returned list includes countries...not ideal but useful later?

# list_name = []
# list_url = []

# for entry in soup.find_all('div', id='all-cities'):
#     for link in entry.find_all('a'):
#         list_name.append(link.text)
#         list_url.append(link.get('href'))
        
# list_url

# %%
# Returns lists of cities/urls only


list_name = []
list_url = []

for entry in soup.find_all('div', id='all-cities'):        # entire table
    for city in entry.find_all('li'):                      # only cities
        for link in city.find_all('a'):                    # grab links
            list_name.append(link.text)
            list_url.append(link.get('href'))

# list_name
# list_url

# %%
# Get corresponding list of countries

current_country = ''
list_country = []

for entry in soup.find_all('div', id='all-cities'):         # entire table
     for link in entry.find_all('a'):                       # grab links
            url = link.get('href')
            name = link.text
            
            if '/country/' in url:                          # common feature to country URLs
                current_country = name                      # update 'Country' label
                pass                                        # not new entry
            else:
                list_country.append(current_country)        # if URL not country, it's a city to label

# list_country

# %%
# Create dataframe from three lists

list_tuples = list(zip(list_name, list_country, list_url))
df = pd.DataFrame(list_tuples, columns = ['City', 'Country', 'URL'])

# %%
# Remove cities lacking any user-contributed data

df_clean = df[~df["URL"].str.contains('/rate/')]          # cities with /rate/ in URL are placeholders without contributions
df_clean.reset_index(drop=True, inplace=True)             

# 2,475 eligible cities (Afghanistan>Kabul ... Zimbabwe>Zvishavane District) 

df_clean
# Out:
#                      City        Country  \
# 0                   Kabul    Afghanistan
# 1               Mariehamn  Aland Islands
# 2                  Durrës        Albania
# 3                 Elbasan        Albania
# 4                   Korçë        Albania
# ...                   ...            ...
# 2470               Kadoma       Zimbabwe
# 2471            Marondera       Zimbabwe
# 2472             Masvingo       Zimbabwe
# 2473               Mutare       Zimbabwe
# 2474  Zvishavane District       Zimbabwe
#
#                                                     URL
# 0       https://www.expatistan.com/cost-of-living/kabul
# 1     https://www.expatistan.com/cost-of-living/mari...
# 2      https://www.expatistan.com/cost-of-living/durres
# 3     https://www.expatistan.com/cost-of-living/elbasan
# 4       https://www.expatistan.com/cost-of-living/korce
# ...                                                 ...
# 2470   https://www.expatistan.com/cost-of-living/kadoma
# 2471  https://www.expatistan.com/cost-of-living/maro...
# 2472  https://www.expatistan.com/cost-of-living/masv...
# 2473   https://www.expatistan.com/cost-of-living/mutare
# 2474  https://www.expatistan.com/cost-of-living/zvis...
#
# [2475 rows x 3 columns]

# %% [markdown]
# 2. 1. Collect A) number of entries and B) number of contributors from each city page
#    2. Sort list of cities descending by A, B
#    3. Filter list to top 1000 cities

# %%
# For cleaning cost-of-living string

def COL_to_float(string):
    
    str_list = string.split(" ")
    cost_raw = str_list[0]
    cost_str = cost_raw.replace('$', '').replace(',', '')
    cost = float(cost_str)
    
    return cost

# %%
# Instantiate empty list for each feature

rent_85m2_expens = []
rent_85m2_normal = []
rent_45m2_expens = []
rent_45m2_normal = []
eatout_lunch = []
eatout_dinner = []
taxi_5mi = []
gas_liter = []
pubtrans_monthly = []
internet_monthly = []
TV_40in = []
cappuccino = []
mobile_wifi_128gb = []

list_n_prices = []
list_n_people = []

list_COL_fam4 = []
list_COL_sin1 = []

# Lists of features for looping

list_feature_texts = ['Monthly rent for 85 m2 (900 sqft) furnished accommodation in expensive area',
                 'Monthly rent for 85 m2 (900 sqft) furnished accommodation in normal area',
                 'Monthly rent for a 45 m2 (480 sqft) furnished studio in expensive area',
                 'Monthly rent for a 45 m2 (480 sqft) furnished studio in normal area',
                 'Basic lunchtime menu (including a drink) in the business district',
                 'Basic dinner out for two in neighborhood pub',
                 'Taxi trip on a business day, basic tariff, 8 km. (5 miles)',
                 '1 liter (1/4 gallon) of gas',
                 'Monthly ticket public transport',
                 'Internet 8 mbps (1 month)',
                 '40” flat screen tv',                     # special quotation mark! (”)
                 'Cappuccino in expat area of the city',
                 'Ipad wi-fi 128gb']

list_feature_names = ['rent_85m2_expens',
                      'rent_85m2_normal',
                      'rent_45m2_expens',
                      'rent_45m2_normal',
                      'eatout_lunch',
                      'eatout_dinner',
                      'taxi_5mi',
                      'gas_liter',
                      'pubtrans_monthly',
                      'internet_monthly',
                      'TV_40in',
                      'cappuccino',
                      'mobile_wifi_128gb']


list_of_lists = [rent_85m2_expens,
                      rent_85m2_normal,
                      rent_45m2_expens,
                      rent_45m2_normal,
                      eatout_lunch,
                      eatout_dinner,
                      taxi_5mi,
                      gas_liter,
                      pubtrans_monthly,
                      internet_monthly,
                      TV_40in,
                      cappuccino,
                      mobile_wifi_128gb]

list_of_urls = list(df_clean["URL"])

# %%
import random
from fake_useragent import UserAgent

for url in list_of_urls:
    
    new_url = url + '?currency=USD'  # generate page version with USD
    
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}                       # new user_agent every iteration
    
    response = requests.get(new_url, headers = user_agent)                       
    page = response.text
    soup_usd = BeautifulSoup(page, "lxml")
    
    # 1. Get price features
    
    for i, feature in enumerate(list_feature_texts):
        chunk1 = soup_usd.find('a', text=feature)
        feature_value = chunk1.findNext().findNext().text[2:-2]
        # if feature_value[0] != '$':                              # causes errors in countries 
        #    feature_value = 'Null'
        
        list_of_lists[i].append(feature_value)
    
    # 2. Get cost of living estimates
    
    if soup_usd.find_all('div', class_='cost-of-living-summary centered right-widget'):    # Summary window must be present
        chunk2 = soup_usd.find('div', class_='cost-of-living-summary centered right-widget')
        COL_fam4_raw = chunk2.find_all('span', class_='price')[0].text
        COL_fam4 = COL_to_float(COL_fam4_raw)
        COL_sin1_raw = chunk2.find_all('span', class_='price')[1].text
        COL_sin1 = COL_to_float(COL_sin1_raw)
    else:
        COL_fam4, COL_sin1 = 'NO_COL', 'NO_COL'
    
    list_COL_sin1.append(COL_sin1)
    list_COL_fam4.append(COL_fam4)
    
    # 3. Get contribution info
    
    chunk3 = soup_usd.find_all('div', class_='accuracy-report')[-1].text       # evaluation always last on page
    sentences = chunk3.split('.')                                              # split into sentences
    sentence_raw = sentences[2].strip()                                        # select 3rd sentence in accuracy-report
    sentence = sentence_raw.replace('less than ', '-')                         # flag cities with scarce data as negative for now
    words = sentence.split(' ')
    no_prices, no_people = words[4], words[8]
    
    list_n_prices.append(no_prices)                               
    list_n_people.append(no_people)
    
    # 4. Pause like a human
    
    wait = .5 + 10 * random.random()
    time.sleep(wait)
    print(f'{url[41:]}, {no_prices}, ${COL_sin1}, waited {wait:0.4} sec.')
# Out:
# /kabul, 206, $619.0, waited 5.96 sec.
# /mariehamn, -10, $1930.0, waited 2.812 sec.
# /durres, -10, $990.0, waited 6.723 sec.
# /elbasan, 31, $624.0, waited 7.856 sec.
# /korce, -10, $1877.0, waited 8.016 sec.
# /shkoder, -10, $583.0, waited 9.224 sec.
# /tirana, 222, $905.0, waited 8.006 sec.
# /vlore, -10, $577.0, waited 1.446 sec.
# /ain-temouchentain-temouchent, -10, $NO_COL, waited 1.697 sec.
# /algiers, 304, $951.0, waited 0.555 sec.
# /batna-city, -10, $440.0, waited 7.365 sec.
# /bechar, -10, $447.0, waited 3.96 sec.
# /bejaia, -10, $NO_COL, waited 2.345 sec.
# /constantine, -10, $538.0, waited 3.511 sec.
# /drean, -10, $NO_COL, waited 1.67 sec.
# /el-eulma, -10, $NO_COL, waited 7.176 sec.
# /khemis-miliana, -10, $689.0, waited 9.36 sec.
# /laghouat, -10, $NO_COL, waited 2.592 sec.
# /medea, -10, $NO_COL, waited 8.944 sec.
# /metlili-chaamba, -10, $835.0, waited 1.737 sec.
# /oran, 81, $708.0, waited 3.544 sec.
# /oum-el-bouaghi, -10, $NO_COL, waited 6.533 sec.
# /sidi-bel-abbes, -10, $NO_COL, waited 6.001 sec.
# /skikda, -10, $NO_COL, waited 1.968 sec.
# /tlemcen, -10, $NO_COL, waited 2.679 sec.
# /andorra-la-vella, 38, $1732.0, waited 9.713 sec.
# /cabinda, -10, $NO_COL, waited 1.577 sec.
# /kuito, -10, $NO_COL, waited 6.34 sec.
# /lobito, -10, $NO_COL, waited 6.605 sec.
# /luanda, 207, $1577.0, waited 0.965 sec.
# /malanje, -10, $NO_COL, waited 6.595 sec.
# /the-valley-anguilla, -10, $NO_COL, waited 3.819 sec.
# /st-johns-antigua-and-barbuda, -10, $1880.0, waited 8.858 sec.
# /bahia-blanca, 421, $568.0, waited 4.46 sec.
# /buenos-aires, 5,504, $852.0, waited 4.343 sec.
# /comodoro-rivadavia, 144, $477.0, waited 10.08 sec.
# /concordia, 84, $468.0, waited 3.044 sec.
# /corrientes, 578, $818.0, waited 6.895 sec.
# /cordoba, 1,112, $612.0, waited 7.6 sec.
# /formosa, 80, $396.0, waited 9.298 sec.
# /la-plata, 372, $627.0, waited 2.706 sec.
# /la-rioja, 135, $494.0, waited 9.385 sec.
# /mar-del-plata, 619, $639.0, waited 4.741 sec.
# /mendoza, 574, $614.0, waited 4.985 sec.
# /neuquen, 394, $794.0, waited 6.191 sec.
# /posadas, 289, $472.0, waited 6.693 sec.
# /quilmes, 227, $455.0, waited 3.413 sec.
# /resistencia, 235, $439.0, waited 2.06 sec.
# /rio-grande-tierra-del-fuego, 177, $427.0, waited 3.087 sec.
# /rosario, 759, $571.0, waited 1.088 sec.
# /rio-cuarto, 131, $463.0, waited 9.732 sec.
# /salta, 125, $689.0, waited 8.916 sec.
# /san-carlos-de-bariloche, 129, $536.0, waited 10.12 sec.
# /san-fernando-del-valle-de-catamarca, 87, $496.0, waited 6.584 sec.
# /san-juan-argentina, 164, $368.0, waited 6.185 sec.
# /san-luis-argentina, 244, $476.0, waited 9.694 sec.
# /san-martin-de-los-andes, 50, $555.0, waited 6.809 sec.
# /san-nicolas-de-los-arroyos, 17, $458.0, waited 6.274 sec.
# /san-rafael, 103, $646.0, waited 2.783 sec.
# /santa-fe-argentina, 271, $529.0, waited 6.047 sec.
# /santa-rosa, 96, $602.0, waited 8.406 sec.
# /santiago-del-estero, 61, $368.0, waited 1.021 sec.
# /tandil, 92, $399.0, waited 1.114 sec.
# /tucuman, 423, $528.0, waited 9.731 sec.
# /ushuaia, 141, $533.0, waited 6.639 sec.
# /gyumri, -10, $NO_COL, waited 7.723 sec.
# /vanadzor, -10, $NO_COL, waited 5.446 sec.
# /yerevan, 168, $825.0, waited 5.629 sec.
# /babijn-aruba, -10, $2323.0, waited 6.029 sec.
# /adelaide, 157, $2123.0, waited 2.557 sec.
# /albury, -10, $2287.0, waited 7.467 sec.
# /ballarat, -10, $1903.0, waited 3.201 sec.
# /brisbane, 424, $2252.0, waited 4.728 sec.
# /cairns, -10, $2076.0, waited 3.591 sec.
# /canberra, 77, $2299.0, waited 7.795 sec.
# /darwin, 14, $2292.0, waited 8.2 sec.
# /dubbo, -10, $2253.0, waited 5.797 sec.
# /geelong, 39, $1693.0, waited 7.227 sec.
# /gold-coast, 45, $2157.0, waited 0.8363 sec.
# /hobart, 92, $2090.0, waited 1.346 sec.
# /mackay, 54, $1821.0, waited 8.227 sec.
# /melbourne, 679, $2657.0, waited 4.598 sec.
# /mildura, -10, $NO_COL, waited 4.623 sec.
# /newcastle-australia, 93, $2259.0, waited 8.84 sec.
# /perth-australia, 286, $2254.0, waited 4.976 sec.
# /sydney, 575, $3481.0, waited 9.778 sec.
# /toowoomba, -10, $1867.0, waited 3.516 sec.
# /townsville, 22, $1994.0, waited 7.946 sec.
# /wollongong, -10, $2217.0, waited 5.786 sec.
# /graz, 112, $1741.0, waited 6.671 sec.
# /innsbruck, 16, $2147.0, waited 1.598 sec.
# /salzburg, -10, $2110.0, waited 8.181 sec.
# /vienna, 282, $2070.0, waited 1.726 sec.
# /villach, -10, $1561.0, waited 2.632 sec.
# /wels, -10, $NO_COL, waited 1.626 sec.
# /baku, 225, $801.0, waited 8.41 sec.
# /ganja, -10, $676.0, waited 2.846 sec.
# /naxcivan, -10, $NO_COL, waited 0.9817 sec.
# /yevlax, 33, $NO_COL, waited 3.091 sec.
# /ski, -10, $NO_COL, waited 2.7 sec.
# /nassau, 22, $2966.0, waited 1.155 sec.
# /manama, 36, $1498.0, waited 9.711 sec.
# /chittagong, 14, $720.0, waited 2.442 sec.
# /comilla, -10, $NO_COL, waited 9.738 sec.
# /coxs-bazars-bazar, 10, $NO_COL, waited 5.916 sec.
# /dhaka, 598, $826.0, waited 1.132 sec.
# /dinajpur, -10, $NO_COL, waited 5.951 sec.
# /feni, -10, $NO_COL, waited 4.218 sec.
# /khulna, -10, $494.0, waited 9.661 sec.
# /kishorganj, -10, $NO_COL, waited 1.0 sec.
# /kushtia, -10, $NO_COL, waited 9.368 sec.
# /moulvi-bazar, -10, $NO_COL, waited 2.688 sec.
# /narail, -10, $NO_COL, waited 5.771 sec.
# /rajshahi, -10, $870.0, waited 2.304 sec.
# /satkhira, -10, $NO_COL, waited 9.558 sec.
# /sylhet, -10, $629.0, waited 7.849 sec.
# /tangail, -10, $NO_COL, waited 6.061 sec.
# /bridgetown, -10, $1808.0, waited 6.666 sec.
# /babruysk, 38, $NO_COL, waited 5.671 sec.
# /baranavichy, -10, $NO_COL, waited 7.41 sec.
# /brest-belarus, 62, $532.0, waited 2.285 sec.
# /homyel, -10, $399.0, waited 1.378 sec.
# /hrodna, 33, $339.0, waited 3.651 sec.
# /lida, 32, $NO_COL, waited 0.7831 sec.
# /mahiliou, 14, $NO_COL, waited 4.542 sec.
# /maladzyechna, -10, $NO_COL, waited 1.869 sec.
# /mazyr, -10, $NO_COL, waited 2.734 sec.
# /minsk, 299, $864.0, waited 6.73 sec.
# /pinsk, -10, $NO_COL, waited 4.364 sec.
# /slonim, -10, $NO_COL, waited 10.44 sec.
# /slutsk, -10, $NO_COL, waited 8.146 sec.
# /vitebsk, -10, $462.0, waited 2.479 sec.
# /zhlobin, -10, $NO_COL, waited 9.647 sec.
# /zhodzina, -10, $NO_COL, waited 6.175 sec.
# /antwerp, 200, $1846.0, waited 6.459 sec.
# /brussels, 223, $1993.0, waited 1.839 sec.
# /ghent, 60, $1775.0, waited 0.8688 sec.
# /hasselt, 32, $1703.0, waited 5.151 sec.
# /leuven, 33, $1728.0, waited 6.998 sec.
# /liege, 107, $1511.0, waited 6.49 sec.
# /mons, 69, $1844.0, waited 2.424 sec.
# /namur, -10, $1721.0, waited 4.362 sec.
# /ostend, -10, $1606.0, waited 8.902 sec.
# /verviers, -10, $NO_COL, waited 10.47 sec.
# /belize-city, 44, $1143.0, waited 2.724 sec.
# /san-pedro-town-belize, -10, $NO_COL, waited 3.111 sec.
# /cotonou, 62, $1019.0, waited 10.42 sec.
# /hamilton-bermuda, 146, $5372.0, waited 7.909 sec.
# /thimphu, -10, $706.0, waited 3.529 sec.
# /cochabamba, 462, $715.0, waited 6.664 sec.
# /la-paz-bolivia, 437, $866.0, waited 2.331 sec.
# /montero, -10, $NO_COL, waited 0.7882 sec.
# /oruro, 46, $581.0, waited 6.463 sec.
# /potosi, -10, $662.0, waited 7.445 sec.
# /riberalta, -10, $NO_COL, waited 2.285 sec.
# /santa-cruz-de-la-sierra, 339, $868.0, waited 8.988 sec.
# /sucre, -10, $1433.0, waited 6.997 sec.
# /tarija, 30, $614.0, waited 3.014 sec.
# /trinidad-bolivia, -10, $NO_COL, waited 6.049 sec.
# /banja-luka, 56, $713.0, waited 9.223 sec.
# /bihac, -10, $562.0, waited 9.042 sec.
# /mostar, -10, $658.0, waited 3.595 sec.
# /sarajevo, 69, $841.0, waited 6.895 sec.
# /tuzla, 15, $627.0, waited 1.237 sec.
# /zenica, -10, $626.0, waited 1.494 sec.
# /francistown, -10, $NO_COL, waited 2.814 sec.
# /gaborone, 35, $979.0, waited 8.46 sec.
# /ananindeua, 37, $627.0, waited 2.033 sec.
# /anapolis, 86, $493.0, waited 9.207 sec.
# /aracaju, 51, $585.0, waited 8.929 sec.
# /araraquara, 43, $722.0, waited 4.678 sec.
# /balneario-camboriu, 152, $756.0, waited 2.501 sec.
# /bauru, 81, $591.0, waited 6.909 sec.
# /belford-roxo, 37, $983.0, waited 3.072 sec.
# /belo-horizonte, 514, $781.0, waited 3.283 sec.
# /belem, 124, $793.0, waited 6.466 sec.
# /blumenau, 176, $624.0, waited 8.015 sec.
# /boa-vista, 56, $645.0, waited 9.662 sec.
# /brasilia, 788, $943.0, waited 6.201 sec.
# /campina-grande, 97, $564.0, waited 6.203 sec.
# /campinas, 327, $888.0, waited 0.8093 sec.
# /campo-grande, 137, $659.0, waited 0.7867 sec.
# /campos, 61, $604.0, waited 2.02 sec.
# /caruaru, -10, $NO_COL, waited 9.971 sec.
# /cascavel, 62, $535.0, waited 6.054 sec.
# /caxias-do-sul, 57, $652.0, waited 6.123 sec.
# /chapeco, 42, $553.0, waited 9.131 sec.
# /contagem, 42, $725.0, waited 6.233 sec.
# /cuiaba, 119, $699.0, waited 7.082 sec.
# /curitiba, 797, $785.0, waited 4.144 sec.
# /divinopolis, 14, $602.0, waited 7.136 sec.
# /duque-de-caxias, 95, $657.0, waited 3.253 sec.
# /feira-de-santana, 38, $463.0, waited 3.277 sec.
# /florianopolis, 301, $927.0, waited 3.489 sec.
# /fortaleza, 475, $692.0, waited 2.183 sec.
# /foz-do-iguacu, 93, $573.0, waited 1.473 sec.
# /franca, 55, $470.0, waited 8.774 sec.
# /goiania, 309, $725.0, waited 3.923 sec.
# /governador-valadares, 172, $502.0, waited 4.015 sec.
# /gramado, 32, $786.0, waited 4.366 sec.
# /guaruja, -10, $682.0, waited 2.264 sec.
# /guarulhos, 18, $691.0, waited 4.904 sec.
# /imperatriz, 51, $761.0, waited 8.849 sec.
# /ipatinga, 33, $451.0, waited 8.677 sec.
# /itabuna, -10, $575.0, waited 7.67 sec.
# /itajuba, -10, $517.0, waited 7.138 sec.
# /jaboatao-brazil, 27, $NO_COL, waited 7.733 sec.
# /jaboatao-dos-guararapes, -10, $NO_COL, waited 8.233 sec.
# /joinville, 311, $621.0, waited 6.954 sec.
# /joao-pessoa, 165, $670.0, waited 5.888 sec.
# /juazeiro-do-norte, -10, $564.0, waited 6.886 sec.
# /juiz-de-fora, 149, $543.0, waited 7.808 sec.
# /jundiai, 77, $735.0, waited 3.297 sec.
# /londrina, 287, $606.0, waited 4.976 sec.
# /macapa, 101, $658.0, waited 4.593 sec.
# /maceio, 70, $672.0, waited 2.171 sec.
# /manaus, 421, $947.0, waited 9.648 sec.
# /maringa, 169, $609.0, waited 8.178 sec.
# /marilia, 84, $559.0, waited 6.231 sec.
# /montes-claros, 13, $657.0, waited 6.216 sec.
# /mossoro, -10, $527.0, waited 8.291 sec.
# /natal, 181, $738.0, waited 4.261 sec.
# /niteroi, 186, $871.0, waited 2.044 sec.
# /nova-iguacu, 30, $597.0, waited 0.9286 sec.
# /novo-hamburgo, 34, $647.0, waited 5.451 sec.
# /orlandia, -10, $NO_COL, waited 3.44 sec.
# /osasco, 67, $862.0, waited 2.521 sec.
# /paulinia, 23, $833.0, waited 0.5933 sec.
# /pelotas, 86, $666.0, waited 6.163 sec.
# /petrolina, -10, $517.0, waited 4.454 sec.
# /petropolis, 64, $656.0, waited 10.34 sec.
# /piracicaba, 34, $714.0, waited 5.675 sec.
# /ponta-grossa, 53, $520.0, waited 2.406 sec.
# /porto-alegre, 404, $788.0, waited 3.197 sec.
# /porto-velho, 63, $740.0, waited 1.801 sec.
# /presidente-prudente, 129, $604.0, waited 9.752 sec.
# /recife, 444, $754.0, waited 4.879 sec.
# /ribeirao-preto, 187, $660.0, waited 2.856 sec.
# /rio-branco, 111, $616.0, waited 9.979 sec.
# /rio-de-janeiro, 1,422, $1008.0, waited 1.107 sec.
# /salvador, 473, $803.0, waited 1.799 sec.
# /santa-barbara-d-oeste, 110, $626.0, waited 9.875 sec.
# /santa-cruz-do-sul, -10, $566.0, waited 1.819 sec.
# /santa-maria, 86, $583.0, waited 9.13 sec.
# /santo-andre, 165, $741.0, waited 1.439 sec.
# /santos-sao-paulo, 327, $943.0, waited 0.9523 sec.
# /sao-joao-de-meriti, -10, $NO_COL, waited 0.7846 sec.
# /sao-joao-del-rei, 47, $481.0, waited 5.028 sec.
# /sao-jose-do-rio-preto, 26, $579.0, waited 3.047 sec.
# /sete-lagoas, 18, $540.0, waited 2.655 sec.
# /sorocaba, 132, $769.0, waited 9.232 sec.
# /sao-bernardo-do-campo, 81, $775.0, waited 2.665 sec.
# /sao-carlos, 27, $594.0, waited 6.803 sec.
# /sao-jose-dos-campos, 487, $788.0, waited 6.817 sec.
# /sao-luis, 257, $804.0, waited 8.963 sec.
# /sao-paulo, 3,040, $1060.0, waited 3.097 sec.
# /teresina, 81, $595.0, waited 2.492 sec.
# /ubatuba, 22, $579.0, waited 3.829 sec.
# /uberaba, 15, $493.0, waited 0.56 sec.
# /uberlandia, 205, $571.0, waited 8.216 sec.
# /vitoria-brazil, 189, $622.0, waited 3.449 sec.
# /vitoria-da-conquista, 99, $503.0, waited 4.742 sec.
# /volta-redonda, 77, $509.0, waited 9.736 sec.
# /road-town, 57, $3095.0, waited 3.135 sec.
# /bandar-seri-begawan, -10, $1570.0, waited 3.63 sec.
# /bansko, -10, $NO_COL, waited 3.789 sec.
# /burgas, -10, $692.0, waited 8.676 sec.
# /gabrovo, 51, $533.0, waited 7.314 sec.
# /khaskovo, -10, $565.0, waited 3.366 sec.
# /pleven, -10, $610.0, waited 1.208 sec.
# /plovdiv, 67, $709.0, waited 8.201 sec.
# /rousse, -10, $602.0, waited 1.688 sec.
# /shumen, -10, $NO_COL, waited 6.352 sec.
# /sliven, -10, $882.0, waited 1.213 sec.
# /sofia, 268, $980.0, waited 5.482 sec.
# /stara-zagora, -10, $644.0, waited 4.697 sec.
# /varna, 70, $892.0, waited 8.937 sec.
# /veliko-tarnovo, 53, $721.0, waited 5.065 sec.
# /vidin, 47, $746.0, waited 9.448 sec.
# /vratsa, -10, $612.0, waited 5.316 sec.
# /yambol, 34, $567.0, waited 4.56 sec.
# /bobo-dioulasso, -10, $NO_COL, waited 8.945 sec.
# /koudougou, -10, $NO_COL, waited 0.8443 sec.
# /ouagadougou, -10, $1210.0, waited 5.739 sec.
# /bujumbura, 34, $1241.0, waited 3.472 sec.
# /battambang, -10, $NO_COL, waited 6.07 sec.
# /kampong-cham, 43, $NO_COL, waited 2.326 sec.
# /kampong-chhnang, -10, $NO_COL, waited 5.706 sec.
# /phnom-penh, 55, $1397.0, waited 8.62 sec.
# /siem-reap, -10, $901.0, waited 8.615 sec.
# /sihanoukville, -10, $NO_COL, waited 6.0 sec.
# /douala, 54, $1176.0, waited 6.531 sec.
# /garoua, -10, $NO_COL, waited 2.565 sec.
# /kousseri, -10, $NO_COL, waited 7.947 sec.
# /kumbo, -10, $NO_COL, waited 7.092 sec.
# /limbe, -10, $NO_COL, waited 9.99 sec.
# /wum, -10, $NO_COL, waited 2.72 sec.
# /yaounde, -10, $1455.0, waited 3.957 sec.
# /abbotsford, -10, $1946.0, waited 3.739 sec.
# /barrie, 96, $2068.0, waited 5.418 sec.
# /brandon-manitoba, 16, $1616.0, waited 9.97 sec.
# /calgary, 301, $1966.0, waited 8.243 sec.
# /charlottetown-pei, 71, $1689.0, waited 8.588 sec.
# /edmonton, 311, $1814.0, waited 5.999 sec.
# /fort-st-john, -10, $2290.0, waited 0.7116 sec.
# /greater-sudbury, 37, $1702.0, waited 3.06 sec.
# /guelph, 57, $1917.0, waited 7.747 sec.
# /halifax, 82, $1897.0, waited 0.8019 sec.
# /hamilton-canada, 76, $1936.0, waited 0.7489 sec.
# /kamloops, -10, $1654.0, waited 6.815 sec.
# /kelowna, 82, $2249.0, waited 5.239 sec.
# /kingston-canada, -10, $1893.0, waited 5.283 sec.
# /kitchener-waterloo, 18, $1793.0, waited 7.23 sec.
# /london-ontario, 246, $1862.0, waited 6.522 sec.
# /mississauga, 55, $2298.0, waited 5.431 sec.
# /moncton, 43, $1554.0, waited 0.7056 sec.
# /montreal, 675, $1851.0, waited 7.102 sec.
# /nanaimo-british-columbia, 83, $1915.0, waited 4.156 sec.
# /oshawa, 100, $2044.0, waited 6.829 sec.
# /ottawa, 180, $2228.0, waited 9.559 sec.
# /prince-george, -10, $1602.0, waited 3.962 sec.
# /quebec-city, 132, $1477.0, waited 1.77 sec.
# /regina, 86, $1815.0, waited 4.039 sec.
# /sarnia, 10, $1479.0, waited 3.103 sec.
# /saskatoon, 31, $1749.0, waited 1.366 sec.
# /sherbrooke, 92, $1213.0, waited 4.97 sec.
# /sparwood-british-columbia, -10, $NO_COL, waited 4.558 sec.
# /st-johns-newfoundland, 139, $1527.0, waited 9.298 sec.
# /thunder-bay-ontario, 12, $1580.0, waited 7.299 sec.
# /toronto, 913, $2740.0, waited 0.7387 sec.
# /trois-rivieres, 130, $1077.0, waited 6.248 sec.
# /vancouver, 769, $2700.0, waited 4.497 sec.
# /victoria-canada, 173, $2374.0, waited 4.157 sec.
# /whitehorse, 45, $2172.0, waited 9.411 sec.
# /windsor, 85, $1552.0, waited 6.683 sec.
# /winnipeg, 248, $1772.0, waited 6.371 sec.
# /yellowknife, -10, $2513.0, waited 5.117 sec.
# /mindelo, 51, $961.0, waited 2.804 sec.
# /praia, 45, $1204.0, waited 4.223 sec.
# /grand-cayman, 177, $4650.0, waited 7.33 sec.
# /bangui, 10, $NO_COL, waited 9.276 sec.
# /berberati, -10, $NO_COL, waited 5.956 sec.
# /abeche, 10, $NO_COL, waited 8.96 sec.
# /n-djamena, -10, $3310.0, waited 2.563 sec.
# /antofagasta, 336, $1253.0, waited 4.4 sec.
# /arica, 36, $962.0, waited 10.12 sec.
# /calama, 30, $1306.0, waited 3.633 sec.
# /chillan, -10, $761.0, waited 7.274 sec.
# /copiapo, 25, $980.0, waited 2.794 sec.
# /curico, 24, $778.0, waited 7.782 sec.
# /iquique, 183, $1053.0, waited 2.194 sec.
# /la-serena, 356, $1010.0, waited 9.691 sec.
# /linares, 26, $830.0, waited 6.85 sec.
# /osorno, 274, $921.0, waited 7.019 sec.
# /ovalle, 57, $883.0, waited 5.691 sec.
# /puerto-montt, 147, $1008.0, waited 8.575 sec.
# /punta-arenas, 207, $1270.0, waited 2.201 sec.
# /rancagua, 141, $950.0, waited 9.174 sec.
# /san-felipe, 51, $1142.0, waited 1.98 sec.
# /santiago-chile, 5,124, $1261.0, waited 4.716 sec.
# /talca, 99, $878.0, waited 0.6484 sec.
# /talcahuano, 172, $936.0, waited 3.532 sec.
# /temuco, 210, $907.0, waited 9.085 sec.
# /valdivia, 244, $922.0, waited 2.706 sec.
# /valparaiso, 320, $936.0, waited 6.437 sec.
# /vina-causino, 16, $1524.0, waited 10.41 sec.
# /aksu, -10, $NO_COL, waited 7.986 sec.
# /anshan, -10, $NO_COL, waited 8.899 sec.
# /anyang-china, -10, $NO_COL, waited 2.933 sec.
# /baoding, -10, $641.0, waited 10.37 sec.
# /baotou, -10, $NO_COL, waited 10.2 sec.
# /beihai, -10, $NO_COL, waited 0.516 sec.
# /beijing, 196, $1961.0, waited 9.205 sec.
# /changchun, -10, $955.0, waited 6.308 sec.
# /changde, -10, $NO_COL, waited 1.008 sec.
# /changsha, 23, $848.0, waited 6.926 sec.
# /changzhi, -10, $NO_COL, waited 9.77 sec.
# /changzhou, -10, $1949.0, waited 8.867 sec.
# /chaozhou, -10, $NO_COL, waited 8.594 sec.
# /chengde, -10, $NO_COL, waited 3.046 sec.
# /chengdu, 147, $1079.0, waited 4.541 sec.
# /chifeng, -10, $NO_COL, waited 9.043 sec.
# /chongqing, 17, $926.0, waited 9.085 sec.
# /dalian, -10, $960.0, waited 5.449 sec.
# /datong, -10, $NO_COL, waited 4.347 sec.
# /dezhou, -10, $671.0, waited 7.579 sec.
# /dongguan, 26, $984.0, waited 7.554 sec.
# /foshan, -10, $812.0, waited 6.577 sec.
# /fushun, -10, $630.0, waited 1.101 sec.
# /fuzhou, -10, $972.0, waited 4.729 sec.
# /guangzhou, 87, $1626.0, waited 8.687 sec.
# /guilin, -10, $711.0, waited 3.514 sec.
# /guiyang, 18, $782.0, waited 5.448 sec.
# /haikou, -10, $NO_COL, waited 4.968 sec.
# /hangzhou, -10, $1412.0, waited 9.931 sec.
# /harbin, 25, $1023.0, waited 7.193 sec.
# /hefei, 59, $797.0, waited 9.373 sec.
# /hengyang, -10, $NO_COL, waited 4.183 sec.
# /heze, 89, $NO_COL, waited 3.315 sec.
# /hohhot, -10, $902.0, waited 3.323 sec.
# /huizhou, -10, $726.0, waited 6.511 sec.
# /jiangmen, -10, $NO_COL, waited 10.46 sec.
# /jiaxing, -10, $NO_COL, waited 1.23 sec.
# /jilin-city, -10, $NO_COL, waited 0.8369 sec.
# /jinan, -10, $818.0, waited 1.488 sec.
# /jingdezhen, -10, $NO_COL, waited 4.326 sec.
# /jining-china, -10, $NO_COL, waited 1.738 sec.
# /jining, -10, $NO_COL, waited 10.35 sec.
# /jinzhou, -10, $NO_COL, waited 6.02 sec.
# /kaifeng, -10, $NO_COL, waited 3.985 sec.
# /kashgar, -10, $NO_COL, waited 0.9302 sec.
# /kunming, 17, $879.0, waited 5.701 sec.
# /lanzhou, -10, $NO_COL, waited 3.338 sec.
# /lhasa, -10, $NO_COL, waited 2.529 sec.
# /lianyungang, -10, $730.0, waited 2.986 sec.
# /lijiang-city, -10, $NO_COL, waited 3.255 sec.
# /linfen, -10, $NO_COL, waited 7.204 sec.
# /linyi, -10, $620.0, waited 9.158 sec.
# /luoyang, 29, $655.0, waited 1.549 sec.
# /mianyang, 58, $657.0, waited 9.105 sec.
# /mudanjiang, -10, $NO_COL, waited 10.45 sec.
# /nanchang, 35, $754.0, waited 8.588 sec.
# /nanjing, 11, $1123.0, waited 2.418 sec.
# /nanning, 16, $NO_COL, waited 0.8207 sec.
# /nantong, -10, $NO_COL, waited 1.738 sec.
# /nanyang, -10, $NO_COL, waited 3.636 sec.
# /neijiang, -10, $NO_COL, waited 8.994 sec.
# /ningbo, -10, $1039.0, waited 3.592 sec.
# /pingdingshan, -10, $NO_COL, waited 2.091 sec.
# /qingdao, 45, $1027.0, waited 1.405 sec.
# /qitaihe, -10, $NO_COL, waited 2.683 sec.
# /rizhao, -10, $1072.0, waited 2.288 sec.
# /shanghai, 342, $3059.0, waited 4.595 sec.
# /shantou, -10, $NO_COL, waited 8.813 sec.
# /shaoxing, -10, $NO_COL, waited 4.785 sec.
# /shenyang, 33, $843.0, waited 8.746 sec.
# /shenzhen, 62, $1886.0, waited 4.073 sec.
# /shihezi, 15, $NO_COL, waited 4.458 sec.
# /shijiazhuang, -10, $785.0, waited 7.179 sec.
# /shiyan, -10, $NO_COL, waited 9.052 sec.
# /suihua, -10, $NO_COL, waited 8.959 sec.
# /suizhou, -10, $NO_COL, waited 6.353 sec.
# /suzhou, 13, $1404.0, waited 10.02 sec.
# /suzhou-china, 13, $1404.0, waited 5.812 sec.
# /taian, -10, $609.0, waited 4.91 sec.
# /taiyuan, 74, $758.0, waited 6.967 sec.
# /taizhou, 18, $NO_COL, waited 1.695 sec.
# /tianjin, 36, $1182.0, waited 6.148 sec.
# /weifang, -10, $718.0, waited 6.774 sec.
# /wenzhou, -10, $950.0, waited 1.685 sec.
# /wuhai, -10, $NO_COL, waited 7.647 sec.
# /wuhan, 34, $885.0, waited 7.741 sec.
# /wuhu, -10, $NO_COL, waited 3.21 sec.
# /wuxi, 10, $1160.0, waited 8.633 sec.
# /wuzhou, -10, $NO_COL, waited 1.728 sec.
# /xiamen, -10, $1193.0, waited 3.912 sec.
# /xian, -10, $788.0, waited 2.848 sec.
# /xiangfan, -10, $NO_COL, waited 5.504 sec.
# /xianyang, -10, $NO_COL, waited 3.486 sec.
# /xingtai, -10, $NO_COL, waited 8.137 sec.
# /xining, -10, $694.0, waited 2.995 sec.
# /xuzhou, -10, $755.0, waited 2.605 sec.
# /yancheng, -10, $NO_COL, waited 7.548 sec.
# /yangzhou, -10, $NO_COL, waited 5.251 sec.
# /yanji, -10, $NO_COL, waited 5.106 sec.
# /yantai, -10, $891.0, waited 4.577 sec.
# /yibin, 24, $NO_COL, waited 8.949 sec.
# /yinchuan, -10, $NO_COL, waited 2.958 sec.
# /yingkou, -10, $NO_COL, waited 2.489 sec.
# /zhengzhou, -10, $824.0, waited 3.245 sec.
# /zhenjiang, -10, $795.0, waited 0.9179 sec.
# /zhuhai, 21, $1046.0, waited 1.149 sec.
# /zibo, 55, $678.0, waited 2.055 sec.
# /urumqi, -10, $NO_COL, waited 4.309 sec.
# /flying-fish-cove-christmas-island, -10, $NO_COL, waited 2.618 sec.
# /armenia-colombia, 119, $602.0, waited 1.433 sec.
# /barrancabermeja, 11, $564.0, waited 3.277 sec.
# /barranquilla, 534, $744.0, waited 10.15 sec.
# /bogota, 4,066, $931.0, waited 0.9933 sec.
# /bucaramanga, 366, $633.0, waited 10.03 sec.
# /buenaventura, 31, $NO_COL, waited 6.465 sec.
# /cartagena-colombia, 297, $818.0, waited 5.776 sec.
# /cucuta, 184, $517.0, waited 10.25 sec.
# /florencia, 32, $NO_COL, waited 3.749 sec.
# /girardot, -10, $504.0, waited 9.222 sec.
# /ibague, 119, $554.0, waited 8.266 sec.
# /maicao, -10, $741.0, waited 1.355 sec.
# /manizales, 130, $633.0, waited 7.207 sec.
# /medellin, 1,037, $819.0, waited 3.392 sec.
# /monteria, 30, $599.0, waited 5.071 sec.
# /neiva, 145, $554.0, waited 8.91 sec.
# /pasto, 77, $503.0, waited 8.464 sec.
# /pereira, 339, $544.0, waited 6.488 sec.
# /santa-marta, 173, $674.0, waited 5.679 sec.
# /santiago-de-cali, 503, $687.0, waited 10.06 sec.
# /sincelejo, 60, $525.0, waited 1.973 sec.
# /sogamoso, 40, $475.0, waited 2.465 sec.
# /tulua, 45, $437.0, waited 3.989 sec.
# /tunja, 14, $525.0, waited 9.109 sec.
# /valledupar, 118, $595.0, waited 2.44 sec.
# /villavicencio, 113, $636.0, waited 7.624 sec.
# /moroni, -10, $NO_COL, waited 3.04 sec.
# /avarua-cook-islands, 36, $1898.0, waited 10.28 sec.
# /limon, 16, $713.0, waited 7.651 sec.
# /san-jose-costa-rica, 1,110, $1149.0, waited 10.02 sec.
# /dubrovnik, -10, $1147.0, waited 9.17 sec.
# /osijek, -10, $827.0, waited 5.066 sec.
# /pula, -10, $954.0, waited 2.104 sec.
# /rijeka, 30, $982.0, waited 2.721 sec.
# /slavonski-brod, -10, $739.0, waited 10.17 sec.
# /split, 69, $1254.0, waited 6.658 sec.
# /zadar, -10, $1078.0, waited 0.8462 sec.
# /zagreb-croatia, 308, $1348.0, waited 3.271 sec.
# /banes, 16, $NO_COL, waited 2.35 sec.
# /bayamo, -10, $NO_COL, waited 2.311 sec.
# /cienfuegos, -10, $2298.0, waited 4.439 sec.
# /corralillo, -10, $NO_COL, waited 8.462 sec.
# /guantanamo, -10, $NO_COL, waited 6.691 sec.
# /guines, -10, $NO_COL, waited 1.065 sec.
# /havana, 1,042, $1026.0, waited 8.851 sec.
# /holguin, 101, $904.0, waited 2.379 sec.
# /las-tunas, 69, $NO_COL, waited 6.274 sec.
# /manzanillo, -10, $NO_COL, waited 8.315 sec.
# /matanzas, 73, $1399.0, waited 7.033 sec.
# /moron, 33, $NO_COL, waited 7.687 sec.
# /nuevitas, 42, $NO_COL, waited 5.015 sec.
# /pinar-del-rio, -10, $NO_COL, waited 7.729 sec.
# /puerto-padre, -10, $NO_COL, waited 8.888 sec.
# /sancti-spiritus, -10, $2205.0, waited 7.414 sec.
# /santa-clara, 54, $1056.0, waited 9.226 sec.
# /santiago-de-cuba, 167, $1187.0, waited 0.7189 sec.
# /trinidad-cuba, 32, $NO_COL, waited 5.132 sec.
# /famagusta, 26, $1074.0, waited 6.995 sec.
# /kyrenia, -10, $1262.0, waited 9.034 sec.
# /larnaca, 48, $1280.0, waited 3.908 sec.
# /limassol, 11, $1755.0, waited 6.835 sec.
# /nicosia, 71, $1480.0, waited 6.365 sec.
# /brno, 78, $1313.0, waited 8.627 sec.
# /chomutov, -10, $944.0, waited 9.849 sec.
# /jihlava, -10, $NO_COL, waited 2.005 sec.
# /karlovy-vary, -10, $1021.0, waited 1.658 sec.
# /liberec, -10, $1011.0, waited 3.993 sec.
# /olomouc, -10, $1056.0, waited 3.292 sec.
# /ostrava, 29, $982.0, waited 1.006 sec.
# /pardubice, 50, $999.0, waited 4.01 sec.
# /pilsen, -10, $959.0, waited 7.762 sec.
# /prague, 305, $1580.0, waited 8.638 sec.
# /zlin, -10, $NO_COL, waited 5.532 sec.
# /usti-nad-labem, -10, $848.0, waited 1.016 sec.
# /ceske-budejovice, -10, $1006.0, waited 3.742 sec.
# /bukavu, -10, $NO_COL, waited 3.142 sec.
# /goma, 13, $1084.0, waited 8.348 sec.
# /kinshasa, 78, $2497.0, waited 8.402 sec.
# /kisangani, -10, $NO_COL, waited 0.6411 sec.
# /lubumbashi, -10, $1781.0, waited 0.9915 sec.
# /mbandaka, -10, $NO_COL, waited 6.105 sec.
# /tshikapa, -10, $NO_COL, waited 5.663 sec.
# /aalborg, -10, $1953.0, waited 10.26 sec.
# /aarhus, 102, $2396.0, waited 8.669 sec.
# /copenhagen, 435, $3359.0, waited 9.841 sec.
# /esbjerg, -10, $2142.0, waited 4.248 sec.
# /horsens, -10, $1935.0, waited 5.467 sec.
# /odense, 60, $2176.0, waited 0.5736 sec.
# /randers, -10, $2401.0, waited 5.088 sec.
# /silkeborg, -10, $3094.0, waited 1.85 sec.
# /vejle, 23, $2131.0, waited 2.469 sec.
# /djibouti, -10, $1812.0, waited 6.716 sec.
# /roseau-dominica, -10, $1069.0, waited 7.578 sec.
# /azua-de-compostela, -10, $NO_COL, waited 8.165 sec.
# /bani-dominican-republic, 10, $NO_COL, waited 0.9273 sec.
# /bonao, -10, $NO_COL, waited 5.911 sec.
# /juan-dolio, -10, $NO_COL, waited 5.984 sec.
# /las-guaranas, -10, $NO_COL, waited 9.203 sec.
# /salvaleon-de-higuey, 60, $733.0, waited 1.138 sec.
# /san-juan-de-la-maguana, 83, $681.0, waited 3.874 sec.
# /santiago-de-los-caballeros, 104, $824.0, waited 7.652 sec.
# /santo-domingo, 500, $959.0, waited 7.118 sec.
# /dili, -10, $2793.0, waited 2.52 sec.
# /babahoyo, 10, $NO_COL, waited 9.969 sec.
# /cuenca, 335, $893.0, waited 8.449 sec.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3v/knnfgj_54zj0mypk_ds4wm_h0000gn/T/ipykernel_3891/4105969203.py in <module>
#      18         chunk1 = soup_usd.find('a', text=feature)
#      19         feature_value = chunk1.findNext().findNext().text[2:-2]
# ---> 20         if feature_value[0] != '$':
#      21             feature_value = 'Null'
#      22
#
# IndexError: string index out of range

# %%
print(rent_85m2_expens[-4], mobile_wifi_128gb[-4])
# Out:
# Null $694

# %%
# Should all be same length
print(len(rent_85m2_expens), len(mobile_wifi_128gb), len(list_COL_sin1), len(list_n_prices))
# Should be length of URL list (2475)
# len(mobile_wifi_128gb)
# Out:
# 581 580 580 580

# %%
# Concatenate into full COL dataset

list_tuples2 = list(zip(rent_85m2_expens,
                      rent_85m2_normal,
                      rent_45m2_expens,
                      rent_45m2_normal,
                      eatout_lunch,
                      eatout_dinner,
                      taxi_5mi,
                      gas_liter,
                      pubtrans_monthly,
                      internet_monthly,
                      TV_40in,
                      cappuccino,
                      mobile_wifi_128gb))

list_tuples3 = list(zip(list_COL_sin1,
                       list_COL_fam4))

list_tuples4 = list(zip(list_n_prices,
                      list_n_people))

df2 = pd.DataFrame(list_tuples2, columns = list_feature_names)
df3 = pd.DataFrame(list_tuples3, columns = ['COL (Family of 4)',
                                            'COL (Single of 1)'])
df4 = pd.DataFrame(list_tuples4, columns = ['No. Prices',
                                            'No. Contributors'])

df_clean2 = pd.concat([df_clean, df2, df3, df4], axis=1)
df_clean2

# %%
# Write df to disk

# %% [markdown]
# ### Selenium starts here

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
def currency_to_usd(url):
    chromedriver = "/Applications/chromedriver" 
    os.environ["webdriver.chrome.driver"] = chromedriver
    
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    time.sleep(20)
    
    currency_dropdown = driver.find_element_by_id('change_currency')
    currency_dropdown.click()
    time.sleep(2)

    currency_dropdown.send_keys("USD - $ (Dollar)")
    time.sleep(2)

    soup_usd = BeautifulSoup(driver.page_source, 'html.parser')
    return soup_usd

# %%
# Raw HTML for navigation (currency unconverted)
# Continue testing with Kabul

driver = webdriver.Chrome(chromedriver)
driver.get('https://www.expatistan.com/cost-of-living/kabul')
time.sleep(2)

currency_dropdown = driver.find_element_by_id('change_currency')
currency_dropdown.click()
time.sleep(2)

currency_dropdown.send_keys("USD - $ (Dollar)")
time.sleep(2)

soup_usd = BeautifulSoup(driver.page_source, 'html.parser')
soup_usd.prettify

# %%
# Get cost of living for single person and family of four

chunk = soup_usd.find('div', class_='cost-of-living-summary centered right-widget')
COL_fam4_str = chunk.find_all('span', class_='price')[0].text
COL_sin1_str = chunk.find_all('span', class_='price')[1].text

print(str_COL_fam4, type(str_COL_fam4))

# %%
# Features

chunk = soup_usd.find('a', text='Monthly rent for 85 m2 (900 sqft) furnished accommodation in expensive area')
rent_85m2_expensive_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Monthly rent for 85 m2 (900 sqft) furnished accommodation in normal area')
rent_85m2_normal_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Monthly rent for a 45 m2 (480 sqft) furnished studio in expensive area')
rent_45m2_expensive_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Monthly rent for a 45 m2 (480 sqft) furnished studio in normal area')
rent_45m2_normal_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Basic lunchtime menu (including a drink) in the business district')
eatout_lunch_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Basic dinner out for two in neighborhood pub')
eatout_dinner_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Taxi trip on a business day, basic tariff, 8 km. (5 miles)')
taxi_5mi_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='1 liter (1/4 gallon) of gas')
gas_liter_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Monthly ticket public transport')
pubtrans_monthly_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Internet 8 mbps')
internet_monthly_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='40\" flat screen tv')
TV_40in_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Cappucino in expat area of the city')
cappucino_str = chunk.findNext().findNext().text[2:-2]

chunk = soup_usd.find('a', text='Ipad wi-fi 128gb')
mobile_wifi_str = chunk.findNext().findNext().text[2:-2]

# %%
# ## Step by step for single city
# # 1. Import HTML from URL as BS object 

# kabul = 'https://www.expatistan.com/cost-of-living/kabul'      # Kabul is df_clean.URL[0]

# response = requests.get(kabul)                              
# # response.status_code

# page = response.text
# soup = BeautifulSoup(page, "lxml")

# # 2. Find corresponding text in BeatifulSoup object

# chunk = soup.find_all('div', class_='accuracy-report')[-1].text       # evaluation always last on page
# sentences = chunk.split('.')                                          # split into sentences
# sentence_raw = sentences[2].strip()                                   # select 3rd sentence in accuracy-report
# sentence = sentence_raw.replace('less than ', '-')                    # flag cities with scarce data as negative for now
# words = sentence.split(' ')
# no_prices, no_people = words[4], words[8]
# contribution_tuple = (no_prices, no_people)

# # 3. Append to corresponding lists

# list_n_prices = []
# list_n_people = []

# n_prices = contribution_tuple[0]
# n_people = contribution_tuple[1]

# list_n_prices.append(n_prices)
# list_n_people.append(n_people)

# print(list_n_prices, list_n_people)    # should be ['206'] ['13'] for Kabul

# %%
# # Define function for getting numbers of contributions/contributors.

# import random
# from fake_useragent import UserAgent

# def get_contribution_info(url):
    
#     ua = UserAgent()
#     user_agent = {'User-agent': ua.random}                                   # new user_agent every iteration
    
#     response = requests.get(url, headers = user_agent)                       
#     page = response.text
#     soup = BeautifulSoup(page, "lxml")
    
#     if soup.find_all('div', class_='cost-of-living-summary centered right-widget'):    # Summary window must be present
#         chunk = soup.find_all('div', class_='accuracy-report')[-1].text                # evaluation always last on page
#         sentences = chunk.split('.')                                                   # split into sentences
#         sentence_raw = sentences[2].strip()                                            # select 3rd sentence in accuracy-report
#         sentence = sentence_raw.replace('less than ', '-')                             # flag cities with scarce data as negative for now
#         words = sentence.split(' ')
#         no_prices, no_people = words[4], words[8]
#     else:
#         no_prices, no_people = 'ERROR', 'ERROR'                        # flagged to filter out later

#     return no_prices, no_people

# %%
# # Scrape contributor info with delay
# # Run overnight

# list_n_prices = []
# list_n_people = []

# for url in list_url2:
    
#     contribution_tuple = get_contribution_info(url)
#     n_prices = contribution_tuple[0]
#     n_people = contribution_tuple[1]
    
#     list_n_prices.append(n_prices)                               
#     list_n_people.append(n_people)
    
#     wait = .5 + 10 * random.random()
#     time.sleep(wait)
#     print(f'{url[41:]}, {n_prices}, {n_people}, waited {wait:0.4} sec.')

# %% [markdown]
# 6. Collect city attributes from Wikipedia (population, latitude, etc.)

# %% [markdown]
# 7. Regression analysis
