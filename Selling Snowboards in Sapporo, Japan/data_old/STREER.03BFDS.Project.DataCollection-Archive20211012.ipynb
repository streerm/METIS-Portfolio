# %%
import numpy as np
import pandas as pd
import geopandas as gpd

from bs4 import BeautifulSoup
import requests
import time, os

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Import 2021 demographic data (DATA-SMART CITY SAPPORO)

# %%
# Import CSV from Sapporo municipal gov't, after editing in Excel (ensure 'header=1')
# Source: DATA-SMART CITY SAPPORO (町名・条丁目別世帯数及び男女別人口 令和3年（2021年）4月1日現在.csv)

df = pd.read_csv('町名・条丁目別_export.csv', header=1)
df.columns = ['Ward', 'Block', 'N_Households_2021',
              "Population_2021", "Male", "Female"]

# %%
# For checking individual entries
# df[df['町条丁目'] == "宮の森一条１０丁目"]

# %% [markdown]
# ### Import shape data (Geoshape Repository)

# %%
# Import SHP from Geoshape Repository > 国勢調査町丁・字等別境界データ
# Source: https://geoshape.ex.nii.ac.jp/ka/

dfgeo_japan = gpd.read_file('h27ka01.shp')
dfgeo_sapp = dfgeo_japan.iloc[:5796, :]  #  清田区→里塚緑ケ丘１２丁目 = last entry for Sapporo City

# %%
# For checking individual entries
# dfgeo_sapp[dfgeo_sapp['S_NAME'] == "宮の森（番地）"]

# %%
# Save Sapporo data as CSV

dfgeo_sapp.to_csv('GISrefdata_for_checking.csv')

# %%
# Reduce feature for data analysis

dfgeo_sapp_cut = dfgeo_sapp[["KEY_CODE",   # unique ID for join in Tableau
                            "PREF_NAME", "CITY_NAME", "S_NAME", "KIGO_E",
                            "AREA", "JINKO", "SETAI",
                            "X_CODE", "Y_CODE"]]

dfgeo_sapp_cut.rename(columns={'JINKO': 'Population_2015', 'SETAI': 'N_Households_2015', 'KIGO_E': 'Kigo_E',
                              'PREF_NAME': 'Pref_ref', 'CITY_NAME': 'Ward_ref', 'S_NAME': 'Block_ref',
                              'AREA': 'Area', "X_CODE": 'Lat', 'Y_CODE': 'Lng'}, inplace=True)

# %% [markdown]
# ### Join datasets on neighborhood

# %%
# Join datasets on ['Ward', 'Block'], ['CITY_NAME', "S_NAME"]

joined_df = pd.merge(df, dfgeo_sapp_cut, left_on=['Ward', 'Block'], right_on=['Ward_ref', 'Block_ref'], how='left')
# new_df = joined_df[joined_df['KEY_CODE'].notna()]
new_df = joined_df[["KEY_CODE",   # unique ID for join in Tableau
                    "Ward", "Block", "Pref_ref", "Ward_ref", "Block_ref", "Kigo_E",
                    "N_Households_2015", "N_Households_2021",
                    "Population_2021", "Population_2015",
                    "Male", "Female", "Area", "Lat", "Lng"]]

# %% [markdown]
# ### Derived features

# %%
# Population density
new_df['PopDen_2015'] = new_df['Population_2015'] / new_df['Area']
new_df['PopDen_2021'] = new_df['Population_2021'] / new_df['Area']

# Gender ratio
new_df['Sex_ratio'] = new_df['Female'] / (new_df['Female'] + new_df['Male'])

# People per household
# Greater values = Families, multigenerational households
new_df["Household_size_2015"] = new_df['Population_2015'] / new_df['N_Households_2015']
new_df["Household_size_2021"] = new_df['Population_2021'] / new_df['N_Households_2021']

new_df
# Out:
#          KEY_CODE Ward          Block Pref_ref Ward_ref Block_ref Kigo_E  \
# 0     01101200002  中央区         大通東２丁目      北海道      中央区    大通東２丁目   None
# 1     01101200003  中央区         大通東３丁目      北海道      中央区    大通東３丁目   None
# 2     01101200004  中央区         大通東４丁目      北海道      中央区    大通東４丁目   None
# 3     01101200005  中央区         大通東５丁目      北海道      中央区    大通東５丁目   None
# 4     01101200006  中央区         大通東６丁目      北海道      中央区    大通東６丁目   None
# ...           ...  ...            ...      ...      ...       ...    ...
# 5593  01109480005  手稲区         明日風５丁目      北海道      手稲区    明日風５丁目   None
# 5594  01109480006  手稲区         明日風６丁目      北海道      手稲区    明日風６丁目   None
# 5595          NaN  手稲区            明日風      NaN      NaN       NaN    NaN
# 5596          NaN  手稲区      　　　合　　　　計      NaN      NaN       NaN    NaN
# 5597          NaN  全　区  全 市 Ｔ Ｏ Ｔ Ａ Ｌ      NaN      NaN       NaN    NaN
#
#       N_Households_2015  N_Households_2021  Population_2021  ...    Male  \
# 0                 142.0                147              276  ...     127
# 1                 267.0                273              414  ...     214
# 2                 167.0                181              290  ...     128
# 3                 143.0                225              264  ...     117
# 4                  97.0                135              266  ...     111
# ...                 ...                ...              ...  ...     ...
# 5593              317.0                414             1238  ...     610
# 5594               38.0                 42              127  ...      57
# 5595                NaN               1458             4400  ...    2167
# 5596                NaN              70509           141918  ...   66871
# 5597                NaN            1082277          1960829  ...  915975
#
#        Female        Area        Lat       Lng  PopDen_2015  PopDen_2021  \
# 0         149   27586.502  141.35944  43.06220     0.009860     0.010005
# 1         200   26893.377  141.36100  43.06240     0.012754     0.015394
# 2         162   26602.436  141.36253  43.06261     0.013119     0.010901
# 3         147   28813.286  141.36423  43.06284     0.006733     0.009162
# 4         155   26944.193  141.36578  43.06299     0.006829     0.009872
# ...       ...         ...        ...       ...          ...          ...
# 5593      628  147336.933  141.23002  43.14310     0.007384     0.008403
# 5594       70   98540.050  141.23316  43.14167     0.001329     0.001289
# 5595     2233         NaN        NaN       NaN          NaN          NaN
# 5596    75047         NaN        NaN       NaN          NaN          NaN
# 5597  1044854         NaN        NaN       NaN          NaN          NaN
#
#       Sex_ratio  Household_size_2015  Household_size_2021
# 0      0.539855             1.915493             1.877551
# 1      0.483092             1.284644             1.516484
# 2      0.558621             2.089820             1.602210
# 3      0.556818             1.356643             1.173333
# 4      0.582707             1.896907             1.970370
# ...         ...                  ...                  ...
# 5593   0.507270             3.432177             2.990338
# 5594   0.551181             3.447368             3.023810
# 5595   0.507500                  NaN             3.017833
# 5596   0.528805                  NaN             2.012764
# 5597   0.532863                  NaN             1.811763
#
# [5598 rows x 21 columns]

# %%
# Export for checking in Numbers
# (10-Oct) Some gaps, but mostly clean

new_df.to_csv('joined_dataframe_for_checking_in_numbers.csv')

# %%
# Remove rows that failed to match (<1% of rows; fix later)

new_df = new_df[new_df['KEY_CODE'].notna()].reset_index(drop=True)

# Convert ID to string for matching in Tableau

new_df['KEY_CODE'] = [str(id_no) for id_no in new_df.KEY_CODE]
new_df
# Out:
#          KEY_CODE Ward   Block Pref_ref Ward_ref Block_ref Kigo_E  \
# 0     01101200002  中央区  大通東２丁目      北海道      中央区    大通東２丁目   None
# 1     01101200003  中央区  大通東３丁目      北海道      中央区    大通東３丁目   None
# 2     01101200004  中央区  大通東４丁目      北海道      中央区    大通東４丁目   None
# 3     01101200005  中央区  大通東５丁目      北海道      中央区    大通東５丁目   None
# 4     01101200006  中央区  大通東６丁目      北海道      中央区    大通東６丁目   None
# ...           ...  ...     ...      ...      ...       ...    ...
# 5382  01109480002  手稲区  明日風２丁目      北海道      手稲区    明日風２丁目   None
# 5383  01109480003  手稲区  明日風３丁目      北海道      手稲区    明日風３丁目   None
# 5384  01109480004  手稲区  明日風４丁目      北海道      手稲区    明日風４丁目   None
# 5385  01109480005  手稲区  明日風５丁目      北海道      手稲区    明日風５丁目   None
# 5386  01109480006  手稲区  明日風６丁目      北海道      手稲区    明日風６丁目   None
#
#       N_Households_2015  N_Households_2021  Population_2021  ...  Male  \
# 0                 142.0                147              276  ...   127
# 1                 267.0                273              414  ...   214
# 2                 167.0                181              290  ...   128
# 3                 143.0                225              264  ...   117
# 4                  97.0                135              266  ...   111
# ...                 ...                ...              ...  ...   ...
# 5382              189.0                203              677  ...   334
# 5383              167.0                209              636  ...   302
# 5384              224.0                327              894  ...   443
# 5385              317.0                414             1238  ...   610
# 5386               38.0                 42              127  ...    57
#
#       Female        Area        Lat       Lng  PopDen_2015  PopDen_2021  \
# 0        149   27586.502  141.35944  43.06220     0.009860     0.010005
# 1        200   26893.377  141.36100  43.06240     0.012754     0.015394
# 2        162   26602.436  141.36253  43.06261     0.013119     0.010901
# 3        147   28813.286  141.36423  43.06284     0.006733     0.009162
# 4        155   26944.193  141.36578  43.06299     0.006829     0.009872
# ...      ...         ...        ...       ...          ...          ...
# 5382     343  152076.985  141.22857  43.13916     0.004373     0.004452
# 5383     334   80237.215  141.22475  43.13927     0.008076     0.007926
# 5384     451   98352.476  141.22645  43.14186     0.007900     0.009090
# 5385     628  147336.933  141.23002  43.14310     0.007384     0.008403
# 5386      70   98540.050  141.23316  43.14167     0.001329     0.001289
#
#       Sex_ratio  Household_size_2015  Household_size_2021
# 0      0.539855             1.915493             1.877551
# 1      0.483092             1.284644             1.516484
# 2      0.558621             2.089820             1.602210
# 3      0.556818             1.356643             1.173333
# 4      0.582707             1.896907             1.970370
# ...         ...                  ...                  ...
# 5382   0.506647             3.518519             3.334975
# 5383   0.525157             3.880240             3.043062
# 5384   0.504474             3.468750             2.733945
# 5385   0.507270             3.432177             2.990338
# 5386   0.551181             3.447368             3.023810
#
# [5387 rows x 21 columns]

# %%
new_df.to_csv('sapporo_df_plus_geodata.csv')

# %% [markdown]
# ### EDA

# %%
# Mask data here
# Limit only districts with population >= 10
df_eda = new_df[((new_df['Population_2021'] >= 10) &
                 (new_df['Sex_ratio'] != 0.0) &
                 (new_df['Sex_ratio'] != 1.0))]

# %%
# Top five blocks with greatest gender imbalance in residents

df_eda.sort_values(by='Sex_ratio', ascending=True)
# Out:
#          KEY_CODE Ward       Block Pref_ref Ward_ref   Block_ref Kigo_E  \
# 3408  01108540001  厚別区     大谷地東１丁目      北海道      厚別区     大谷地東１丁目   None
# 932   01102241813   北区   北十八条西１３丁目      北海道       北区   北十八条西１３丁目   None
# 505   01101692610  中央区  南二十六条西１０丁目      北海道      中央区  南二十六条西１０丁目   None
# 422   01101691805  中央区    南十八条西５丁目      北海道      中央区    南十八条西５丁目   None
# 994   01102242507   北区   北二十五条西７丁目      北海道       北区   北二十五条西７丁目   None
# ...           ...  ...         ...      ...      ...         ...    ...
# 3724  01105110001  豊平区    月寒中央通１丁目      北海道      豊平区    月寒中央通１丁目   None
# 4565  01107030101   西区   二十四軒一条１丁目      北海道       西区   二十四軒一条１丁目   None
# 2309  01103233608   東区   北三十六条東８丁目      北海道       東区   北三十六条東８丁目   None
# 128   01101690314  中央区    南三条西１４丁目      北海道      中央区    南三条西１４丁目   None
# 971   01102242313   北区  北二十三条西１３丁目      北海道       北区  北二十三条西１３丁目   None
#
#       N_Households_2015  N_Households_2021  Population_2021  ...  Male  \
# 3408                4.0                 27               30  ...    26
# 932                 6.0                170              170  ...   143
# 505                 0.0                177              177  ...   148
# 422                 9.0                  7               10  ...     8
# 994                38.0                 32               43  ...    34
# ...                 ...                ...              ...  ...   ...
# 3724                9.0                 11               15  ...     3
# 4565                4.0                  4               10  ...     2
# 2309               18.0                  8               10  ...     2
# 128                 0.0                 26               26  ...     2
# 971                16.0                 43               43  ...     1
#
#       Female        Area        Lat       Lng  PopDen_2015  PopDen_2021  \
# 3408       4  119684.802  141.45026  43.03041     0.000092     0.000251
# 932       27   10175.106  141.33140  43.08028     0.052284     0.016707
# 505       29   23661.132  141.34674  43.02464     0.000000     0.007481
# 422        2    3658.023  141.35447  43.03683     0.004647     0.002734
# 994        9   14146.541  141.33874  43.09153     0.004312     0.003040
# ...      ...         ...        ...       ...          ...          ...
# 3724      12   10796.239  141.39220  43.03788     0.001852     0.001389
# 4565       8   38377.716  141.31800  43.07360     0.000261     0.000261
# 2309       8    9576.182  141.35823  43.10584     0.004804     0.001044
# 128       24    4614.702  141.33492  43.05472     0.000000     0.005634
# 971       42   19491.468  141.32995  43.08747     0.005028     0.002206
#
#       Sex_ratio  Household_size_2015  Household_size_2021
# 3408   0.133333             2.750000             1.111111
# 932    0.158824            88.666667             1.000000
# 505    0.163842                  NaN             1.000000
# 422    0.200000             1.888889             1.428571
# 994    0.209302             1.605263             1.343750
# ...         ...                  ...                  ...
# 3724   0.800000             2.222222             1.363636
# 4565   0.800000             2.500000             2.500000
# 2309   0.800000             2.555556             1.250000
# 128    0.923077                  NaN             1.000000
# 971    0.976744             6.125000             1.000000
#
# [5268 rows x 21 columns]

# %%
# Top five blocks with largest/smallest households

df_eda.sort_values(by='Household_size_2021', ascending=True)
